# %%
import pandas as pd

# %%
archivos = !ls | grep '.csv'

# %%
archivos
# Out:
# ['April2018.csv',
#  'April2019.csv',
#  'August2018.csv',
#  'August2019.csv',
#  'cleandataset.csv',
#  'December2018.csv',
#  'February2019.csv',
#  'January2019.csv',
#  'July2018.csv',
#  'July2019.csv',
#  'June2018.csv',
#  'June2019.csv',
#  'March2019.csv',
#  'May2018.csv',
#  'May2019.csv',
#  'November2018.csv',
#  'November2019.csv',
#  'October2018.csv',
#  'October2019.csv',
#  'September2018.csv',
#  'September2019.csv']

# %%
df1 = pd.read_csv('April2019.csv')
df2 = pd.read_csv("January2019.csv")
df3 = pd.read_csv('April2018.csv')
# Out:
# /home/guillem/anaconda3/envs/tfmenv/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (43,61,62) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# df1 = pd.read_csv('April2019.csv')
# df2 = pd.read_csv('August2019.csv')
# df3 = pd.read_csv('February2019.csv')
# df4 = pd.read_csv('July2019.csv')
# df5 = pd.read_csv('June2019.csv')
# df6 = pd.read_csv('March2019.csv')
# df7 = pd.read_csv('May2019.csv')
# df8 = pd.read_csv('November2019.csv')
# df9 = pd.read_csv('October2019.csv')
# df10 = pd.read_csv('September2019.csv')
# df11 = pd.read_cvs('January2019')

# %%
dfD = df1.append(df2, ignore_index = True).append(df3, ignore_index = True)

# %%
dfD.groupby('id').count()
# Out:
#           listing_url  scrape_id  last_scraped  name  summary  space  \
# id
# 18653               1          1             1     1        1      1
# 18666               3          3             3     3        3      3
# 18674               3          3             3     3        3      3
# 19157               1          1             1     1        1      1
# 20345               1          1             1     1        1      1
# ...               ...        ...           ...   ...      ...    ...
# 33765131            1          1             1     1        1      1
# 33765133            1          1             1     1        1      1
# 33765134            1          1             1     1        1      1
# 33766303            1          1             1     1        1      0
# 33771392            1          1             1     1        1      0
#
#           description  experiences_offered  neighborhood_overview  notes  ...  \
# id                                                                        ...
# 18653               1                    1                      1      0  ...
# 18666               3                    3                      3      0  ...
# 18674               3                    3                      3      0  ...
# 19157               1                    1                      1      1  ...
# 20345               1                    1                      1      1  ...
# ...               ...                  ...                    ...    ...  ...
# 33765131            1                    1                      0      0  ...
# 33765133            1                    1                      0      0  ...
# 33765134            1                    1                      0      0  ...
# 33766303            1                    1                      0      0  ...
# 33771392            1                    1                      1      0  ...
#
#           instant_bookable  is_business_travel_ready  cancellation_policy  \
# id
# 18653                    1                         1                    1
# 18666                    3                         3                    3
# 18674                    3                         3                    3
# 19157                    1                         1                    1
# 20345                    1                         1                    1
# ...                    ...                       ...                  ...
# 33765131                 1                         1                    1
# 33765133                 1                         1                    1
# 33765134                 1                         1                    1
# 33766303                 1                         1                    1
# 33771392                 1                         1                    1
#
#           require_guest_profile_picture  require_guest_phone_verification  \
# id
# 18653                                 1                                 1
# 18666                                 3                                 3
# 18674                                 3                                 3
# 19157                                 1                                 1
# 20345                                 1                                 1
# ...                                 ...                               ...
# 33765131                              1                                 1
# 33765133                              1                                 1
# 33765134                              1                                 1
# 33766303                              1                                 1
# 33771392                              1                                 1
#
#           calculated_host_listings_count  \
# id
# 18653                                  1
# 18666                                  3
# 18674                                  3
# 19157                                  1
# 20345                                  1
# ...                                  ...
# 33765131                               1
# 33765133                               1
# 33765134                               1
# 33766303                               1
# 33771392                               1
#
#           calculated_host_listings_count_entire_homes  \
# id
# 18653                                               0
# 18666                                               2
# 18674                                               2
# 19157                                               0
# 20345                                               0
# ...                                               ...
# 33765131                                            1
# 33765133                                            1
# 33765134                                            1
# 33766303                                            1
# 33771392                                            1
#
#           calculated_host_listings_count_private_rooms  \
# id
# 18653                                                0
# 18666                                                2
# 18674                                                2
# 19157                                                0
# 20345                                                0
# ...                                                ...
# 33765131                                             1
# 33765133                                             1
# 33765134                                             1
# 33766303                                             1
# 33771392                                             1
#
#           calculated_host_listings_count_shared_rooms  reviews_per_month
# id
# 18653                                               0                  0
# 18666                                               2                  3
# 18674                                               2                  3
# 19157                                               0                  1
# 20345                                               0                  1
# ...                                               ...                ...
# 33765131                                            1                  0
# 33765133                                            1                  0
# 33765134                                            1                  0
# 33766303                                            1                  0
# 33771392                                            1                  0
#
# [29859 rows x 105 columns]

# %%
dfD.columns[dfD.columns.str.endswith('id')]
# Out:
# Index(['id', 'scrape_id', 'host_id'], dtype='object')

# %%
dfD[dfD['id'] == 18674]['price']
# Out:
# 1        $60.00
# 17900    $60.00
# 44478    $95.00
# Name: price, dtype: object

# %%
dfD['last_scraped'].value_counts()
# Out:
# 2018-04-12    19153
# 2019-04-10    17899
# 2019-01-14    11660
# 2019-01-15     6373
# 2018-04-13       15
# Name: last_scraped, dtype: int64

# %%
dfD['year'] = [x[0] for x in dfD.iloc[:]['last_scraped'].str.split('-')]
dfD['month'] = [x[1] for x in dfD.iloc[:]['last_scraped'].str.split('-')]

# %%
dfD.groupby(['year', 'month']).count()['bed_type']
# Out:
# year  month
# 2018  04       19168
# 2019  01       18033
#       04       17899
# Name: bed_type, dtype: int64

# %%
dfD.sort_values(by = ['year', 'month'], inplace = True)

# %% [markdown]
# df1 = pd.read_csv('September2019.csv')
# df2 = pd.read_csv('October2019.csv')
# df3 = pd.read_csv('November2019.csv')

# %% [markdown]
# df1.shape, df2.shape, df3.shape

# %% [markdown]
# dfD = df1.append(df2, ignore_index = True).append(df3, ignore_index = True)

# %%
dfD
# Out:
#              id                            listing_url       scrape_id  \
# 35932   8127277   https://www.airbnb.com/rooms/8127277  20180412002537
# 35933  10172298  https://www.airbnb.com/rooms/10172298  20180412002537
# 35934  10735872  https://www.airbnb.com/rooms/10735872  20180412002537
# 35935  19432305  https://www.airbnb.com/rooms/19432305  20180412002537
# 35936  20956172  https://www.airbnb.com/rooms/20956172  20180412002537
# ...         ...                                    ...             ...
# 17894  33765131  https://www.airbnb.com/rooms/33765131  20190410191814
# 17895  33765133  https://www.airbnb.com/rooms/33765133  20190410191814
# 17896  33765134  https://www.airbnb.com/rooms/33765134  20190410191814
# 17897  33766303  https://www.airbnb.com/rooms/33766303  20190410191814
# 17898  33771392  https://www.airbnb.com/rooms/33771392  20190410191814
#
#       last_scraped                                               name  \
# 35932   2018-04-12                Room for 4 people with bathroom pri
# 35933   2018-04-12                          Quiet loft with courtyard
# 35934   2018-04-12                       Luxury Duplex en Sant Antoni
# 35935   2018-04-12                                    The green suite
# 35936   2018-04-12  Beautiful Room In The Heart Of BCN ( Las Rambl...
# ...            ...                                                ...
# 17894   2019-04-10                      Apartment Ultimate experience
# 17895   2019-04-10                      Apartment Ultimate experience
# 17896   2019-04-10                      Apartment Ultimate experience
# 17897   2019-04-10  Sunny Apartment 100 m. from the Beach in Barce...
# 17898   2019-04-10    Fantastic room in the center of Bcn, near beach
#
#                                                  summary  \
# 35932  Room with private bathroom, TV, wifi, air cond...
# 35933  We are renting this year our apartment in Barc...
# 35934  NEW REFORMED LUXURY DUPLEX near metro Sant Ant...
# 35935  33 meter squares loft-apartment with beautiful...
# 35936  This beautiful newly furnished room is located...
# ...                                                  ...
# 17894  My calendar is not sychronising; so to avoid b...
# 17895  My calendar is not sychronising; so to avoid b...
# 17896  My calendar is not sychronising; so to avoid b...
# 17897  Apartment on the beachfront, with sea orientat...
# 17898  Habitación en Barcelona en piso totalmente ref...
#
#                                                    space  \
# 35932  My 144 m2 apartment was renovated in 2013. It ...
# 35933  The apartment is situated 5 minutes walking fr...
# 35934  Spectacular Duplex in the heart of Barcelona, ...
# 35935                                                NaN
# 35936                                                NaN
# ...                                                  ...
# 17894  A modern 4 bedrooms and 4 bathrooms in the hea...
# 17895  A modern 4 bedrooms and 4 bathrooms in the hea...
# 17896  A modern 4 bedrooms and 4 bathrooms in the hea...
# 17897                                                NaN
# 17898                                                NaN
#
#                                              description experiences_offered  \
# 35932  Room with private bathroom, TV, wifi, air cond...                none
# 35933  We are renting this year our apartment in Barc...                none
# 35934  NEW REFORMED LUXURY DUPLEX near metro Sant Ant...                none
# 35935  33 meter squares loft-apartment with beautiful...                none
# 35936  This beautiful newly furnished room is located...                none
# ...                                                  ...                 ...
# 17894  My calendar is not sychronising; so to avoid b...                none
# 17895  My calendar is not sychronising; so to avoid b...                none
# 17896  My calendar is not sychronising; so to avoid b...                none
# 17897  Apartment on the beachfront, with sea orientat...                none
# 17898  Habitación en Barcelona en piso totalmente ref...                none
#
#                                    neighborhood_overview  ...  \
# 35932  Raval is a lively multicultural neighborhood w...  ...
# 35933  The area is widely multicultural, lively and c...  ...
# 35934  The centric neighbourhood of Barcelona - EL RA...  ...
# 35935                                                NaN  ...
# 35936  Please respect the neighbours by being extra q...  ...
# ...                                                  ...  ...
# 17894                                                NaN  ...
# 17895                                                NaN  ...
# 17896                                                NaN  ...
# 17897                                                NaN  ...
# 17898  El Born es un barrio a la última caracterizado...  ...
#
#                cancellation_policy require_guest_profile_picture  \
# 35932                     moderate                             f
# 35933                       strict                             f
# 35934                       strict                             f
# 35935                       strict                             f
# 35936                       strict                             f
# ...                            ...                           ...
# 17894                     flexible                             f
# 17895                     flexible                             f
# 17896                     flexible                             f
# 17897  strict_14_with_grace_period                             f
# 17898                     flexible                             f
#
#       require_guest_phone_verification calculated_host_listings_count  \
# 35932                                f                              8
# 35933                                f                              1
# 35934                                f                             11
# 35935                                f                              1
# 35936                                f                              8
# ...                                ...                            ...
# 17894                                f                              3
# 17895                                f                              3
# 17896                                f                              3
# 17897                                f                              1
# 17898                                f                              2
#
#       calculated_host_listings_count_entire_homes  \
# 35932                                         NaN
# 35933                                         NaN
# 35934                                         NaN
# 35935                                         NaN
# 35936                                         NaN
# ...                                           ...
# 17894                                         3.0
# 17895                                         3.0
# 17896                                         3.0
# 17897                                         1.0
# 17898                                         0.0
#
#        calculated_host_listings_count_private_rooms  \
# 35932                                           NaN
# 35933                                           NaN
# 35934                                           NaN
# 35935                                           NaN
# 35936                                           NaN
# ...                                             ...
# 17894                                           0.0
# 17895                                           0.0
# 17896                                           0.0
# 17897                                           0.0
# 17898                                           2.0
#
#        calculated_host_listings_count_shared_rooms reviews_per_month  year  \
# 35932                                          NaN              0.59  2018
# 35933                                          NaN              0.25  2018
# 35934                                          NaN              0.10  2018
# 35935                                          NaN              0.21  2018
# 35936                                          NaN              1.03  2018
# ...                                            ...               ...   ...
# 17894                                          0.0               NaN  2019
# 17895                                          0.0               NaN  2019
# 17896                                          0.0               NaN  2019
# 17897                                          0.0               NaN  2019
# 17898                                          0.0               NaN  2019
#
#        month
# 35932     04
# 35933     04
# 35934     04
# 35935     04
# 35936     04
# ...      ...
# 17894     04
# 17895     04
# 17896     04
# 17897     04
# 17898     04
#
# [55100 rows x 108 columns]

# %%
dfD.columns
# Out:
# Index(['id', 'listing_url', 'scrape_id', 'last_scraped', 'name', 'summary',
#        'space', 'description', 'experiences_offered', 'neighborhood_overview',
#        ...
#        'cancellation_policy', 'require_guest_profile_picture',
#        'require_guest_phone_verification', 'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month'],
#       dtype='object', length=108)

# %%
dfD.columns.str.endswith('url')
# Out:
# array([False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True,  True,
#         True, False,  True, False, False, False, False, False, False,
#        False, False,  True,  True, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False])

# %%
dropC = dfD.columns[dfD.columns.str.endswith('url')]
dfD.drop(dropC, axis = 1, inplace = True)

# %%
nulls = []
for row, index in zip(dfD.isnull().sum(), dfD.isnull().sum().index):
    nulls.append([index, row])
nulls = pd.DataFrame(nulls).set_index(0)
nulls
# Out:
#                                                   1
# 0
# id                                                0
# scrape_id                                         0
# last_scraped                                      0
# name                                             63
# summary                                        2210
# ...                                             ...
# calculated_host_listings_count_private_rooms  19168
# calculated_host_listings_count_shared_rooms   19168
# reviews_per_month                             11305
# year                                              0
# month                                             0
#
# [100 rows x 1 columns]

# %%
nulls_percent = nulls.loc[nulls[1]>0]/dfD.shape[0]
nulls_percent.loc[nulls_percent[1]>0.5]
# Out:
#                              1
# 0
# notes                 0.517840
# host_acceptance_rate  1.000000
# square_feet           0.969546
# weekly_price          0.912142
# monthly_price         0.904755
# license               0.544592
# jurisdiction_names    1.000000

# %%
dropC = nulls_percent.loc[nulls_percent[1]>0.5].index
dropC
# Out:
# Index(['notes', 'host_acceptance_rate', 'square_feet', 'weekly_price',
#        'monthly_price', 'license', 'jurisdiction_names'],
#       dtype='object', name=0)

# %%
dfD.drop(dropC, axis = 1, inplace = True)
dfD.head()
# Out:
#              id       scrape_id last_scraped  \
# 35932   8127277  20180412002537   2018-04-12
# 35933  10172298  20180412002537   2018-04-12
# 35934  10735872  20180412002537   2018-04-12
# 35935  19432305  20180412002537   2018-04-12
# 35936  20956172  20180412002537   2018-04-12
#
#                                                     name  \
# 35932                Room for 4 people with bathroom pri
# 35933                          Quiet loft with courtyard
# 35934                       Luxury Duplex en Sant Antoni
# 35935                                    The green suite
# 35936  Beautiful Room In The Heart Of BCN ( Las Rambl...
#
#                                                  summary  \
# 35932  Room with private bathroom, TV, wifi, air cond...
# 35933  We are renting this year our apartment in Barc...
# 35934  NEW REFORMED LUXURY DUPLEX near metro Sant Ant...
# 35935  33 meter squares loft-apartment with beautiful...
# 35936  This beautiful newly furnished room is located...
#
#                                                    space  \
# 35932  My 144 m2 apartment was renovated in 2013. It ...
# 35933  The apartment is situated 5 minutes walking fr...
# 35934  Spectacular Duplex in the heart of Barcelona, ...
# 35935                                                NaN
# 35936                                                NaN
#
#                                              description experiences_offered  \
# 35932  Room with private bathroom, TV, wifi, air cond...                none
# 35933  We are renting this year our apartment in Barc...                none
# 35934  NEW REFORMED LUXURY DUPLEX near metro Sant Ant...                none
# 35935  33 meter squares loft-apartment with beautiful...                none
# 35936  This beautiful newly furnished room is located...                none
#
#                                    neighborhood_overview  \
# 35932  Raval is a lively multicultural neighborhood w...
# 35933  The area is widely multicultural, lively and c...
# 35934  The centric neighbourhood of Barcelona - EL RA...
# 35935                                                NaN
# 35936  Please respect the neighbours by being extra q...
#
#                                                  transit  ...  \
# 35932  The apartment has very good communication, wal...  ...
# 35933  The apartment is 5 min walk to 3 metro lines: ...  ...
# 35934  Discover Barcelona and walk a lot, however you...  ...
# 35935                                                NaN  ...
# 35936                                                NaN  ...
#
#       cancellation_policy require_guest_profile_picture  \
# 35932            moderate                             f
# 35933              strict                             f
# 35934              strict                             f
# 35935              strict                             f
# 35936              strict                             f
#
#       require_guest_phone_verification  calculated_host_listings_count  \
# 35932                                f                               8
# 35933                                f                               1
# 35934                                f                              11
# 35935                                f                               1
# 35936                                f                               8
#
#       calculated_host_listings_count_entire_homes  \
# 35932                                         NaN
# 35933                                         NaN
# 35934                                         NaN
# 35935                                         NaN
# 35936                                         NaN
#
#       calculated_host_listings_count_private_rooms  \
# 35932                                          NaN
# 35933                                          NaN
# 35934                                          NaN
# 35935                                          NaN
# 35936                                          NaN
#
#       calculated_host_listings_count_shared_rooms reviews_per_month  year  \
# 35932                                         NaN              0.59  2018
# 35933                                         NaN              0.25  2018
# 35934                                         NaN              0.10  2018
# 35935                                         NaN              0.21  2018
# 35936                                         NaN              1.03  2018
#
#       month
# 35932    04
# 35933    04
# 35934    04
# 35935    04
# 35936    04
#
# [5 rows x 93 columns]

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview',
#        'transit', 'access', 'interaction', 'house_rules', 'host_id',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'city', 'state', 'zipcode', 'market',
#        'smart_location', 'country_code', 'country', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'amenities', 'price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'minimum_minimum_nights',
#        'maximum_minimum_nights', 'minimum_maximum_nights',
#        'maximum_maximum_nights', 'minimum_nights_avg_ntm',
#        'maximum_nights_avg_ntm', 'calendar_updated', 'has_availability',
#        'availability_30', 'availability_60', 'availability_90',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month'],
#       dtype='object')

# %% [markdown]
# # COLUMNA A DISCUTIR

# %%
dfD['city'].value_counts()
# Out:
# Barcelona                                   53274
# BARCELONA                                     703
# L'Hospitalet de Llobregat                     465
# Barcelona                                      97
# barcelona                                      79
#                                             ...
# Badalona                                        1
# 08014 BARCELONA                                 1
#  Barcelona (Metro L1) Hostafrancs               1
# Montcada i Reixac                               1
# L'Hospitalet de Llobregat, Catalunya, ES        1
# Name: city, Length: 69, dtype: int64

# %%
dfD['country'].value_counts()
# Out:
# Spain    55100
# Name: country, dtype: int64

# %%
dfD['state'].value_counts()
# Out:
# Catalunya                    38287
# Catalonia                     7357
# Barcelona                     2978
# CT                            2619
# Cataluña                      1131
#                              ...
# spain                            1
# Catalanes                        1
# L’Hospitalet de Llobregat        1
# Каталонія                        1
# CT08025                          1
# Name: state, Length: 78, dtype: int64

# %%
dfD.loc[dfD['state'] == 'Connecticut'][['city', 'neighbourhood']]
# Out:
#             city neighbourhood
# 46078  Barcelona   Sant Antoni
# 21576  Barcelona           NaN
# 21742  Barcelona           NaN

# %%
dfD.loc[dfD['city']=="L'Hospitalet de Llobregat"]['neighbourhood'].value_counts()
# Out:
# Sants-Montjuïc                285
# La Maternitat i Sant Ramon    122
# Les Corts                      55
# Name: neighbourhood, dtype: int64

# %%
dfD.loc[dfD['city']=="."]['neighbourhood'].value_counts()
# Out:
# Dreta de l'Eixample            7
# Eixample                       5
# Diagonal Mar - La Mar Bella    3
# Sant Pere/Santa Caterina       2
# Ciutat Vella                   1
# El Gòtic                       1
# Sant Martí                     1
# Name: neighbourhood, dtype: int64

# %%
dropC = ['city', 'state', 'zipcode', 'country', 'country_code']
dfD.drop(dropC, axis = 1, inplace = True)

# %%
maxmincols = [x for x in dfD.columns if (x.startswith('maximum') | x.startswith('minimum'))]
maxmincols
# Out:
# ['minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm']

# %%
dfD[maxmincols]
# Out:
#        minimum_nights  maximum_nights  minimum_minimum_nights  \
# 35932              31              90                     NaN
# 35933              30            1125                     NaN
# 35934              32             360                     NaN
# 35935              31            1125                     NaN
# 35936              30            1125                     NaN
# ...               ...             ...                     ...
# 17894               3            1125                     3.0
# 17895               3            1125                     3.0
# 17896               3            1125                     3.0
# 17897              31            1125                    31.0
# 17898               4            1125                     4.0
#
#        maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 35932                     NaN                     NaN                     NaN
# 35933                     NaN                     NaN                     NaN
# 35934                     NaN                     NaN                     NaN
# 35935                     NaN                     NaN                     NaN
# 35936                     NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 17894                     3.0                  1125.0                  1125.0
# 17895                     3.0                  1125.0                  1125.0
# 17896                     3.0                  1125.0                  1125.0
# 17897                    31.0                  1125.0                  1125.0
# 17898                     4.0                  1125.0                  1125.0
#
#        minimum_nights_avg_ntm  maximum_nights_avg_ntm
# 35932                     NaN                     NaN
# 35933                     NaN                     NaN
# 35934                     NaN                     NaN
# 35935                     NaN                     NaN
# 35936                     NaN                     NaN
# ...                       ...                     ...
# 17894                     3.0                  1125.0
# 17895                     3.0                  1125.0
# 17896                     3.0                  1125.0
# 17897                    31.0                  1125.0
# 17898                     4.0                  1125.0
#
# [55100 rows x 8 columns]

# %%
for col in [x for x in dfD.columns if 'minimum' in x]:
    print('La columna {} coincide con la de minimum_nigths un {:.2f}%'
          .format(col, ((dfD.loc[:]['minimum_nights'] == dfD.loc[:][col]).sum()/dfD.shape[0])*100))
# Out:
# La columna minimum_nights coincide con la de minimum_nigths un 100.00%
# La columna minimum_minimum_nights coincide con la de minimum_nigths un 58.17%
# La columna maximum_minimum_nights coincide con la de minimum_nigths un 50.64%
# La columna minimum_maximum_nights coincide con la de minimum_nigths un 0.45%
# La columna minimum_nights_avg_ntm coincide con la de minimum_nigths un 50.23%

# %%
for col in [x for x in dfD.columns if 'maximum' in x]:
    print('La columna {} coincide con la de minimum_nigths un {:.2f}%'
          .format(col, ((dfD.loc[:]['maximum_nights'] == dfD.loc[:][col]).sum()/dfD.shape[0])*100))
# Out:
# La columna maximum_nights coincide con la de minimum_nigths un 100.00%
# La columna maximum_minimum_nights coincide con la de minimum_nigths un 0.34%
# La columna minimum_maximum_nights coincide con la de minimum_nigths un 63.59%
# La columna maximum_maximum_nights coincide con la de minimum_nigths un 64.03%
# La columna maximum_nights_avg_ntm coincide con la de minimum_nigths un 63.39%

# %%
[x for x in dfD.columns if 'minimum' in x]
# Out:
# ['minimum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'minimum_nights_avg_ntm']

# %%
DropC = [x for x in maxmincols if x not in ['minimum_nights', 'maximum_nights']]
print(len(maxmincols), len(DropC))
DropC
# Out:
# 8 6
# ['minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm']

# %%
dfD.drop(DropC, axis = 1, inplace = True)

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview',
#        'transit', 'access', 'interaction', 'house_rules', 'host_id',
#        'host_name', 'host_since', 'host_location', 'host_about',
#        'host_response_time', 'host_response_rate', 'host_is_superhost',
#        'host_neighbourhood', 'host_listings_count',
#        'host_total_listings_count', 'host_verifications',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'market', 'smart_location', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month'],
#       dtype='object')

# %%
dfD[['neighbourhood', 'neighbourhood_cleansed', 'neighbourhood_group_cleansed']]
# Out:
#       neighbourhood                 neighbourhood_cleansed  \
# 35932      El Raval                               el Raval
# 35933      El Raval                               el Raval
# 35934      El Raval                               el Raval
# 35935      El Raval                               el Raval
# 35936      El Raval                               el Raval
# ...             ...                                    ...
# 17894  Ciutat Vella                         el Barri Gòtic
# 17895      El Gòtic                         el Barri Gòtic
# 17896      El Gòtic                         el Barri Gòtic
# 17897    Sant Martí          la Vila Olímpica del Poblenou
# 17898      El Gòtic  Sant Pere, Santa Caterina i la Ribera
#
#       neighbourhood_group_cleansed
# 35932                 Ciutat Vella
# 35933                 Ciutat Vella
# 35934                 Ciutat Vella
# 35935                 Ciutat Vella
# 35936                 Ciutat Vella
# ...                            ...
# 17894                 Ciutat Vella
# 17895                 Ciutat Vella
# 17896                 Ciutat Vella
# 17897                   Sant Martí
# 17898                 Ciutat Vella
#
# [55100 rows x 3 columns]

# %%
dfD['neighbourhood'].value_counts()
# Out:
# Dreta de l'Eixample    4576
# Sants-Montjuïc         4240
# El Raval               3652
# Eixample               3522
# El Gòtic               2669
#                        ...
# La Vall d'Hebron         27
# La Trinitat Vella        27
# Trinitat Nova            25
# Torre Baró               19
# Baró de Viver             4
# Name: neighbourhood, Length: 69, dtype: int64

# %%
dfD['neighbourhood_cleansed'].value_counts()
# Out:
# la Dreta de l'Eixample                   5855
# el Raval                                 4333
# el Barri Gòtic                           3426
# Sant Pere, Santa Caterina i la Ribera    3113
# la Vila de Gràcia                        3070
#                                          ...
# Torre Baró                                 26
# Canyelles                                  13
# Baró de Viver                              11
# Vallbona                                    8
# la Clota                                    1
# Name: neighbourhood_cleansed, Length: 72, dtype: int64

# %%
dfD['neighbourhood_group_cleansed'].value_counts()
# Out:
# Eixample               18664
# Ciutat Vella           11972
# Sants-Montjuïc          6675
# Sant Martí              6118
# Gràcia                  4867
# Sarrià-Sant Gervasi     2067
# Horta-Guinardó          1742
# Les Corts               1358
# Sant Andreu              960
# Nou Barris               677
# Name: neighbourhood_group_cleansed, dtype: int64

# %%
host_keys = [x for x in dfD.columns if x.startswith('host')]
host_keys
# Out:
# ['host_id',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified']

# %%
dfD[host_keys].sample(10)
# Out:
#          host_id          host_name  host_since  \
# 51237    1448949           Hortense  2011-11-28
# 38623   38459913             Carles  2015-07-14
# 9871   157250994  Apartment Barcino  2017-11-03
# 707      1432835              Angel  2011-11-22
# 49913   14979846            Natalia  2014-05-01
# 23332    7414663       Happy People  2013-07-11
# 17992     567180         Suite Home  2011-05-08
# 32433   40635037               Beth  2015-08-05
# 13689   23940792               Mire  2014-11-19
# 46945   36187810    Martin & Andrés  2015-06-19
#
#                               host_location  \
# 51237           Barcelona, Catalonia, Spain
# 38623  Cornellà del Terri, Catalunya, Spain
# 9871            Barcelona, Catalonia, Spain
# 707              Barcelona, Cataluña, Spain
# 49913           Barcelona, Catalonia, Spain
# 23332           Barcelona, Catalonia, Spain
# 17992            Barcelona, Cataluña, Spain
# 32433           Barcelona, Catalonia, Spain
# 13689           Barcelona, Catalonia, Spain
# 46945           Barcelona, Catalonia, Spain
#
#                                               host_about  host_response_time  \
# 51237  Bonjour, I am Hortense, French girl, 32 years ...        within a day
# 38623                                                NaN                 NaN
# 9871   Somos una empresa familiar de alquiler de apar...  within a few hours
# 707    Hi everyone! I'm an easygoing person who loves...      within an hour
# 49913                        Seria, Responsable, Honesta  within a few hours
# 23332  English: \r\nWe are a young, enthusiastic and ...  within a few hours
# 17992  "Welcome to your home” is our slogan, but we w...        within a day
# 32433  Soy una argentina, mama de tres, viviendo en B...                 NaN
# 13689                                                NaN        within a day
# 46945  We are an Anglo/Colombian couple who enjoy mee...  within a few hours
#
#       host_response_rate host_is_superhost               host_neighbourhood  \
# 51237                70%                 t                   Vila de Gràcia
# 38623                NaN                 f                              NaN
# 9871                100%                 f           Sant Gervasi - Galvany
# 707                 100%                 f  L'Antiga Esquerra de l'Eixample
# 49913               100%                 f       Sant Gervasi - la Bonanova
# 23332                75%                 f         Sant Pere/Santa Caterina
# 17992                90%                 f               la Sagrada Familia
# 32433                NaN                 t              Dreta de l'Eixample
# 13689                60%                 t                      Sant Antoni
# 46945               100%                 t                              NaN
#
#        host_listings_count  host_total_listings_count  \
# 51237                  3.0                        3.0
# 38623                  1.0                        1.0
# 9871                  54.0                       54.0
# 707                   38.0                       38.0
# 49913                  9.0                        9.0
# 23332                 32.0                       32.0
# 17992                  9.0                        9.0
# 32433                  5.0                        5.0
# 13689                  1.0                        1.0
# 46945                  1.0                        1.0
#
#                                       host_verifications host_has_profile_pic  \
# 51237             ['email', 'phone', 'reviews', 'jumio']                    t
# 38623             ['email', 'phone', 'reviews', 'jumio']                    t
# 9871   ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 707    ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 49913  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 23332  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 17992  ['email', 'phone', 'reviews', 'jumio', 'selfie...                    t
# 32433  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 13689                                 ['email', 'phone']                    t
# 46945  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
#
#       host_identity_verified
# 51237                      t
# 38623                      t
# 9871                       f
# 707                        f
# 49913                      t
# 23332                      t
# 17992                      f
# 32433                      t
# 13689                      f
# 46945                      t

# %%
dfD['host_verifications'].value_counts()
# Out:
# ['email', 'phone', 'reviews']                                                                                    7588
# ['email', 'phone', 'reviews', 'jumio', 'government_id']                                                          7024
# ['email', 'phone']                                                                                               5141
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'selfie', 'government_id', 'identity_manual']    4421
# ['email', 'phone', 'reviews', 'jumio', 'offline_government_id', 'government_id']                                 3028
#                                                                                                                  ...
# ['email', 'phone', 'manual_online', 'reviews', 'manual_offline', 'jumio', 'sent_id', 'government_id']               1
# ['email', 'phone', 'manual_offline', 'jumio', 'government_id']                                                      1
# ['email', 'phone', 'google', 'reviews', 'offline_government_id', 'selfie', 'government_id']                         1
# ['email', 'phone', 'reviews', 'jumio', 'kba', 'work_email']                                                         1
# ['email', 'phone', 'facebook', 'reviews', 'weibo', 'jumio']                                                         1
# Name: host_verifications, Length: 412, dtype: int64

# %%
host_keys = [x for x in dfD.columns if x.startswith('host')]
host_keys
# Out:
# ['host_id',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_is_superhost',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified']

# %%
dfD['host_emailverified'] = dfD['host_verifications'].apply(lambda x: 1 if 'email' in x else 0)
dfD['host_phoneverified'] = dfD['host_verifications'].apply(lambda x: 1 if 'phone' in x else 0)
dfD['host_hasjumio'] = dfD['host_verifications'].apply(lambda x: 1 if 'jumio' in x else 0)
dfD['host_reviewverified'] = dfD['host_verifications'].apply(lambda x: 1 if 'review' in x else 0)
dfD['host_selfieverified'] = dfD['host_verifications'].apply(lambda x: 1 if 'selfie' in x else 0)

# %%
dfD.loc[dfD['host_emailverified'] == 0][['host_verifications', 'host_emailverified']]
# Out:
#                                       host_verifications  host_emailverified
# 36025                               ['phone', 'reviews']                   0
# 36028     ['phone', 'reviews', 'jumio', 'government_id']                   0
# 36031                                          ['phone']                   0
# 36040                               ['phone', 'reviews']                   0
# 36046                                               None                   0
# ...                                                  ...                 ...
# 17877                                          ['phone']                   0
# 17888                                          ['phone']                   0
# 17894  ['phone', 'offline_government_id', 'government...                   0
# 17895  ['phone', 'offline_government_id', 'government...                   0
# 17896  ['phone', 'offline_government_id', 'government...                   0
#
# [2941 rows x 2 columns]

# %%
dfD[['host_verifications', 'host_emailverified']].sample(20)
# Out:
#                                       host_verifications  host_emailverified
# 22752  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 14426  ['email', 'phone', 'reviews', 'jumio', 'govern...                   1
# 43141                      ['email', 'phone', 'reviews']                   1
# 10968  ['email', 'phone', 'jumio', 'offline_governmen...                   1
# 34747                                 ['email', 'phone']                   1
# 15323                                 ['email', 'phone']                   1
# 9469   ['email', 'phone', 'google', 'reviews', 'offli...                   1
# 37376                      ['email', 'phone', 'reviews']                   1
# 43013                              ['phone', 'facebook']                   0
# 50851  ['email', 'phone', 'facebook', 'reviews', 'jum...                   1
# 47509  ['email', 'phone', 'reviews', 'jumio', 'govern...                   1
# 51538                      ['email', 'phone', 'reviews']                   1
# 20073  ['email', 'phone', 'facebook', 'reviews', 'jum...                   1
# 33623  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 23197                      ['email', 'phone', 'reviews']                   1
# 13024  ['email', 'phone', 'offline_government_id', 's...                   1
# 7468   ['email', 'phone', 'facebook', 'reviews', 'jum...                   1
# 52606                      ['email', 'phone', 'reviews']                   1
# 47259  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 26410                      ['email', 'phone', 'reviews']                   1

# %% [markdown]
# dfD['host_emailverified'] = ['email' in dfD.iloc[i]['host_verifications'] for i in range(dfD.shape[0])]
# dfD['host_phoneverified'] = ['phone' in dfD.iloc[i]['host_verifications'] for i in range(dfD.shape[0])]
# dfD['host_hasjumio'] = ['jumio' in dfD.iloc[i]['host_verifications'] for i in range(dfD.shape[0])]
# dfD['host_reviewverified'] = ['review' in dfD.iloc[i]['host_verifications'] for i in range(dfD.shape[0])]
# dfD['host_selfieverified'] = ['selfie' in dfD.iloc[i]['host_verifications'] for i in range(dfD.shape[0])]

# %% [markdown]
# host_emailverified = []
# for i in range(dfD.shape[0]):
#     if 'email' in dfD.iloc[i]['host_verifications']:
#         host_emailverified.append(1)
#     else:
#         host_emailverified.append(0)
# host_emailverified = pd.Series(host_emailverified)
# dfD['host_emailverified'] = host_emailverified

# %% [markdown]
# host_phoneverified = []
# for i in range(dfD.shape[0]):
#     if 'phone' in dfD.iloc[i]['host_verifications']:
#         host_phoneverified.append(1)
#     else:
#         host_phoneverified.append(0)
# host_phoneverified = pd.Series(host_phoneverified)
# dfD['host_phoneverified'] = host_phoneverified

# %% [markdown]
# host_hasjumio = []
# for i in range(dfD.shape[0]):
#     if 'jumio' in dfD.iloc[i]['host_verifications']:
#         host_hasjumio.append(1)
#     else:
#         host_hasjumio.append(0)
# host_hasjumio = pd.Series(host_hasjumio)
# dfD['host_hasjumio'] = host_hasjumio

# %% [markdown]
# host_reviewverified = []
# for i in range(dfD.shape[0]):
#     if 'reviews' in dfD.iloc[i]['host_verifications']:
#         host_reviewverified.append(1)
#     else:
#         host_reviewverified.append(0)
# host_reviewverified = pd.Series(host_reviewverified)
# dfD['host_reviewverified'] = host_reviewverified

# %% [markdown]
# host_selfieverified = []
# for i in range(dfD.shape[0]):
#     if 'selfie' in dfD.iloc[i]['host_verifications']:
#         host_selfieverified.append(1)
#     else:
#         host_selfieverified.append(0)
# host_selfieverified = pd.Series(host_selfieverified)
# dfD['host_selfieverified'] = host_selfieverified

# %%
dfD[['host_verifications', 'host_emailverified', 'host_phoneverified', 'host_hasjumio']].sample(20)
# Out:
#                                       host_verifications  host_emailverified  \
# 40812        ['email', 'phone', 'reviews', 'work_email']                   1
# 42694                      ['email', 'phone', 'reviews']                   1
# 47811  ['email', 'phone', 'facebook', 'reviews', 'jum...                   1
# 54902  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 29248  ['email', 'phone', 'facebook', 'reviews', 'jum...                   1
# 23493                      ['email', 'phone', 'reviews']                   1
# 37069                      ['email', 'phone', 'reviews']                   1
# 40966  ['email', 'phone', 'facebook', 'google', 'revi...                   1
# 31908  ['email', 'phone', 'jumio', 'offline_governmen...                   1
# 28060  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 30247             ['email', 'phone', 'reviews', 'jumio']                   1
# 30677                                 ['email', 'phone']                   1
# 10771                              ['phone', 'facebook']                   0
# 271    ['email', 'phone', 'reviews', 'jumio', 'govern...                   1
# 20217          ['email', 'phone', 'facebook', 'reviews']                   1
# 12124  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 41121                               ['phone', 'reviews']                   0
# 18982  ['email', 'phone', 'reviews', 'jumio', 'offlin...                   1
# 4503   ['email', 'phone', 'reviews', 'jumio', 'govern...                   1
# 19770  ['email', 'phone', 'reviews', 'jumio', 'govern...                   1
#
#        host_phoneverified  host_hasjumio
# 40812                   1              0
# 42694                   1              0
# 47811                   1              1
# 54902                   1              1
# 29248                   1              1
# 23493                   1              0
# 37069                   1              0
# 40966                   1              1
# 31908                   1              1
# 28060                   1              1
# 30247                   1              1
# 30677                   1              0
# 10771                   1              0
# 271                     1              1
# 20217                   1              0
# 12124                   1              1
# 41121                   1              0
# 18982                   1              1
# 4503                    1              1
# 19770                   1              1

# %%
dfD[['host_emailverified', 'host_phoneverified', 'host_hasjumio', 'host_selfieverified', 'host_reviewverified']].sum()/dfD.shape[0]
# Out:
# host_emailverified     0.946624
# host_phoneverified     0.992178
# host_hasjumio          0.603285
# host_selfieverified    0.228203
# host_reviewverified    0.779710
# dtype: float64

# %%
host_keys = [x for x in dfD.columns if x.startswith('host')]
dfD[host_keys]
# Out:
#          host_id            host_name  host_since  \
# 35932   42906962                 Luis  2015-08-30
# 35933   52226755            Kristofer  2015-12-25
# 35934    1093718               Alexey  2011-08-31
# 35935  136236479                 Jude  2017-06-21
# 35936  108269759               Prissa  2016-12-23
# ...          ...                  ...         ...
# 17894   19021831  Jocelyn And Malcolm  2014-07-28
# 17895   19021831  Jocelyn And Malcolm  2014-07-28
# 17896   19021831  Jocelyn And Malcolm  2014-07-28
# 17897   18194979               Carlos  2014-07-16
# 17898  194880697                Maria  2018-06-11
#
#                                host_location  \
# 35932            Barcelona, Catalonia, Spain
# 35933            Barcelona, Catalonia, Spain
# 35934             Barcelona, Cataluña, Spain
# 35935                                     ES
# 35936            Barcelona, Catalonia, Spain
# ...                                      ...
# 17894  Boulder, Western Australia, Australia
# 17895  Boulder, Western Australia, Australia
# 17896  Boulder, Western Australia, Australia
# 17897            Barcelona, Catalonia, Spain
# 17898            Barcelona, Catalonia, Spain
#
#                                               host_about  host_response_time  \
# 35932                                                NaN      within an hour
# 35933                                                NaN      within an hour
# 35934  We are More Ryadom NET, managers of many apart...  within a few hours
# 35935                                                NaN  within a few hours
# 35936  I'm a social person that likes to travel and l...      within an hour
# ...                                                  ...                 ...
# 17894                                                NaN      within an hour
# 17895                                                NaN      within an hour
# 17896                                                NaN      within an hour
# 17897  Natural de Salou, viviendo en Barcelona desde ...  within a few hours
# 17898                                                NaN      within an hour
#
#       host_response_rate host_is_superhost     host_neighbourhood  \
# 35932               100%                 f               El Raval
# 35933               100%                 f                    NaN
# 35934               100%                 f  El Besòs i el Maresme
# 35935               100%                 f                    NaN
# 35936               100%                 f       La Vila Olímpica
# ...                  ...               ...                    ...
# 17894               100%                 f                Mayfair
# 17895               100%                 f                Mayfair
# 17896               100%                 f                Mayfair
# 17897               100%                 f       La Vila Olímpica
# 17898               100%                 f                El Born
#
#        host_listings_count  host_total_listings_count  \
# 35932                  8.0                        8.0
# 35933                  1.0                        1.0
# 35934                 23.0                       23.0
# 35935                  1.0                        1.0
# 35936                  8.0                        8.0
# ...                    ...                        ...
# 17894                 76.0                       76.0
# 17895                 76.0                       76.0
# 17896                 76.0                       76.0
# 17897                  3.0                        3.0
# 17898                  2.0                        2.0
#
#                                       host_verifications host_has_profile_pic  \
# 35932  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 35933                      ['email', 'phone', 'reviews']                    t
# 35934  ['email', 'phone', 'facebook', 'reviews', 'man...                    t
# 35935                      ['email', 'phone', 'reviews']                    t
# 35936                      ['email', 'phone', 'reviews']                    t
# ...                                                  ...                  ...
# 17894  ['phone', 'offline_government_id', 'government...                    t
# 17895  ['phone', 'offline_government_id', 'government...                    t
# 17896  ['phone', 'offline_government_id', 'government...                    t
# 17897  ['email', 'phone', 'google', 'reviews', 'jumio...                    t
# 17898                                 ['email', 'phone']                    t
#
#       host_identity_verified  host_emailverified  host_phoneverified  \
# 35932                      t                   1                   1
# 35933                      f                   1                   1
# 35934                      t                   1                   1
# 35935                      f                   1                   1
# 35936                      f                   1                   1
# ...                      ...                 ...                 ...
# 17894                      f                   0                   1
# 17895                      f                   0                   1
# 17896                      f                   0                   1
# 17897                      f                   1                   1
# 17898                      f                   1                   1
#
#        host_hasjumio  host_reviewverified  host_selfieverified
# 35932              1                    1                    0
# 35933              0                    1                    0
# 35934              1                    1                    0
# 35935              0                    1                    0
# 35936              0                    1                    0
# ...              ...                  ...                  ...
# 17894              0                    0                    0
# 17895              0                    0                    0
# 17896              0                    0                    0
# 17897              1                    1                    1
# 17898              0                    0                    0
#
# [55100 rows x 19 columns]

# %%
(dfD.iloc[:]['host_listings_count'] == dfD.iloc[:]['host_total_listings_count']).sum()
# Out:
# 55059

# %%
print(dfD['host_listings_count'].isnull().sum())
dfD['host_total_listings_count'].isnull().sum()
# Out:
# 41
# 41

# %%
dropC = ['host_name','host_about', 'host_neighbourhood', 'host_listings_count', 'host_verifications']
dfD.drop(dropC, axis = 1, inplace = True)

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'experiences_offered', 'neighborhood_overview',
#        'transit', 'access', 'interaction', 'house_rules', 'host_id',
#        'host_since', 'host_location', 'host_response_time',
#        'host_response_rate', 'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'street',
#        'neighbourhood', 'neighbourhood_cleansed',
#        'neighbourhood_group_cleansed', 'market', 'smart_location', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type',
#        'amenities', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'calendar_updated', 'has_availability', 'availability_30',
#        'availability_60', 'availability_90', 'availability_365',
#        'calendar_last_scraped', 'number_of_reviews', 'number_of_reviews_ltm',
#        'first_review', 'last_review', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'instant_bookable', 'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month', 'host_emailverified', 'host_phoneverified',
#        'host_hasjumio', 'host_reviewverified', 'host_selfieverified'],
#       dtype='object')

# %%
dfD[dfD.columns[:7]].sample(10)
# Esto se puede utilizar para NLP
# Out:
#              id       scrape_id last_scraped  \
# 9803   21721327  20190410191814   2019-04-10
# 26618  18913927  20190114203115   2019-01-15
# 46973  24285544  20180412002537   2018-04-12
# 40263  24037098  20180412002537   2018-04-12
# 28020  20899279  20190114203115   2019-01-14
# 17100  32971481  20190410191814   2019-04-10
# 23942  13554575  20190114203115   2019-01-14
# 16209  32177860  20190410191814   2019-04-10
# 27162  19629513  20190114203115   2019-01-14
# 43820    721479  20180412002537   2018-04-12
#
#                                                     name  \
# 9803                         Central 2 bedroom apartment
# 26618                  Sunny Double Room 50mt by the Sea
# 46973                                          Bcn Apt 2
# 40263             Beautiful room on Eixample, BCN center
# 28020  Cozy room with comfortable double bed near cen...
# 17100    ZEN DOUBLE ROOM IN THE HEART OF BARCELONA *****
# 23942                 St. Anthony - Sunny 3 BR apartment
# 16209      Camino Hostel, double or 2 singles beds room.
# 27162       Cozy room with private bathroom in Barcelona
# 43820            2 Sicilia Superior Apartment 4 bedrooms
#
#                                                  summary  \
# 9803   This apartment in Barcelona is located in the ...
# 26618  Sunny and cosy room in a small typical apartme...
# 46973  Centric housing located in Barcelona, in one o...
# 40263  Hola! Dispongo de una preciosa habitación en e...
# 28020  We offer a cozy and private room with double b...
# 17100  Beautiful room in a renovated luxury apartment...
# 23942  Welcome to our pretty apartment located next t...
# 16209  Camino hostel is located in Poblesec/Montjuic ...
# 27162  Spacious double room with private bathroom in ...
# 43820                                                NaN
#
#                                                    space  \
# 9803                                                 NaN
# 26618  Guests have full access to all the service of ...
# 46973  It is composed of 1 room, with comfortable dou...
# 40263                                                NaN
# 28020  Our apartment is located in a central area and...
# 17100  Completely newly renovated apartment with a vi...
# 23942  The apartment has three bedrooms, two bathroom...
# 16209  This is a double or 2 single beds room. It's o...
# 27162                                                NaN
# 43820  APARTMENT DESCRIPTION New and large apartment ...
#
#                                              description
# 9803   This apartment in Barcelona is located in the ...
# 26618  Sunny and cosy room in a small typical apartme...
# 46973  Centric housing located in Barcelona, in one o...
# 40263  Hola! Dispongo de una preciosa habitación en e...
# 28020  We offer a cozy and private room with double b...
# 17100  Beautiful room in a renovated luxury apartment...
# 23942  Welcome to our pretty apartment located next t...
# 16209  Camino hostel is located in Poblesec/Montjuic ...
# 27162  Spacious double room with private bathroom in ...
# 43820  APARTMENT DESCRIPTION New and large apartment ...

# %%
dfD[dfD.columns[7:14]]
# Out:
#       experiences_offered                              neighborhood_overview  \
# 35932                none  Raval is a lively multicultural neighborhood w...
# 35933                none  The area is widely multicultural, lively and c...
# 35934                none  The centric neighbourhood of Barcelona - EL RA...
# 35935                none                                                NaN
# 35936                none  Please respect the neighbours by being extra q...
# ...                   ...                                                ...
# 17894                none                                                NaN
# 17895                none                                                NaN
# 17896                none                                                NaN
# 17897                none                                                NaN
# 17898                none  El Born es un barrio a la última caracterizado...
#
#                                                  transit  \
# 35932  The apartment has very good communication, wal...
# 35933  The apartment is 5 min walk to 3 metro lines: ...
# 35934  Discover Barcelona and walk a lot, however you...
# 35935                                                NaN
# 35936                                                NaN
# ...                                                  ...
# 17894                                                NaN
# 17895                                                NaN
# 17896                                                NaN
# 17897                                                NaN
# 17898  Solo a 2 minutos caminando del metro, y a 5 mi...
#
#                                                   access  \
# 35932  You can freely use the common areas such as th...
# 35933  Our guests will have access to the whole apart...
# 35934  The whole apartment is your. Enjoy your stay i...
# 35935                                                NaN
# 35936  Kitchen, dinning area and washrooms accessible...
# ...                                                  ...
# 17894                                                NaN
# 17895                                                NaN
# 17896                                                NaN
# 17897                                                NaN
# 17898                                                NaN
#
#                                              interaction  \
# 35932  I will be available during your visit for ever...
# 35933  We live in the area so we are normally availab...
# 35934  Any question, any problem I and my coworkers a...
# 35935                                                NaN
# 35936       I will be availible to answer any questions.
# ...                                                  ...
# 17894                                                NaN
# 17895                                                NaN
# 17896                                                NaN
# 17897                                                NaN
# 17898                                                NaN
#
#                                              house_rules    host_id
# 35932  We know you will understand and respect these ...   42906962
# 35933  Smoking is not allowed inside the house. The c...   52226755
# 35934  1. Save Energy for you, for me and for the env...    1093718
# 35935  Smoking- only in the balcony Noise-  though th...  136236479
# 35936  Please make your showers short in the mornings...  108269759
# ...                                                  ...        ...
# 17894                                                NaN   19021831
# 17895                                                NaN   19021831
# 17896                                                NaN   19021831
# 17897                                                NaN   18194979
# 17898                                                NaN  194880697
#
# [55100 rows x 7 columns]

# %%
dfD['experiences_offered'].value_counts()
# Out:
# none    55100
# Name: experiences_offered, dtype: int64

# %%
dfD['experiences_offered']
dfD.drop('experiences_offered', axis = 1, inplace = True)

# %%
dfD[dfD.columns[14:21]]
# Out:
#                                host_location  host_response_time  \
# 35932            Barcelona, Catalonia, Spain      within an hour
# 35933            Barcelona, Catalonia, Spain      within an hour
# 35934             Barcelona, Cataluña, Spain  within a few hours
# 35935                                     ES  within a few hours
# 35936            Barcelona, Catalonia, Spain      within an hour
# ...                                      ...                 ...
# 17894  Boulder, Western Australia, Australia      within an hour
# 17895  Boulder, Western Australia, Australia      within an hour
# 17896  Boulder, Western Australia, Australia      within an hour
# 17897            Barcelona, Catalonia, Spain  within a few hours
# 17898            Barcelona, Catalonia, Spain      within an hour
#
#       host_response_rate host_is_superhost  host_total_listings_count  \
# 35932               100%                 f                        8.0
# 35933               100%                 f                        1.0
# 35934               100%                 f                       23.0
# 35935               100%                 f                        1.0
# 35936               100%                 f                        8.0
# ...                  ...               ...                        ...
# 17894               100%                 f                       76.0
# 17895               100%                 f                       76.0
# 17896               100%                 f                       76.0
# 17897               100%                 f                        3.0
# 17898               100%                 f                        2.0
#
#       host_has_profile_pic host_identity_verified
# 35932                    t                      t
# 35933                    t                      f
# 35934                    t                      t
# 35935                    t                      f
# 35936                    t                      f
# ...                    ...                    ...
# 17894                    t                      f
# 17895                    t                      f
# 17896                    t                      f
# 17897                    t                      f
# 17898                    t                      f
#
# [55100 rows x 7 columns]

# %%
dfD['host_response_time'].value_counts(dropna = False, normalize = True)
# Out:
# within an hour        0.537604
# NaN                   0.208603
# within a few hours    0.132196
# within a day          0.097713
# a few days or more    0.023884
# Name: host_response_time, dtype: float64

# %%
dfD['host_response_time'].fillna('undetermined', inplace = True)

# %%
dfD['host_response_time'].value_counts(dropna = False, normalize = True)
# Out:
# within an hour        0.537604
# undetermined          0.208603
# within a few hours    0.132196
# within a day          0.097713
# a few days or more    0.023884
# Name: host_response_time, dtype: float64

# %%
dfD['host_response_rate'] = dfD['host_response_rate'].str.replace('%', '')

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
rs_notnull = dfD.loc[dfD['host_response_rate'].isnull()== False]['host_response_rate'].astype('int')

# %%
rs_notnull[rs_notnull > 90].count()/rs_notnull.shape[0]
# Out:
# 0.8144292069898638

# %%
plt.subplots(1, 1, figsize = (12, 8))
plt.hist(rs_notnull[rs_notnull > 50])
plt.show()

# %%
dfD.drop('host_response_rate', axis = 1, inplace = True)

# %% [markdown]
# **¿Qué hacemos con los Nulls?**

# %%
variablesdicotomicas = ['host_is_superhost', 'host_has_profile_pic', 'host_identity_verified']
for variable in variablesdicotomicas:
    dfD[variable] = dfD[variable].apply(lambda x: 1 if x == 't' else 0)

dfD[variablesdicotomicas]
# Out:
#        host_is_superhost  host_has_profile_pic  host_identity_verified
# 35932                  0                     1                       1
# 35933                  0                     1                       0
# 35934                  0                     1                       1
# 35935                  0                     1                       0
# 35936                  0                     1                       0
# ...                  ...                   ...                     ...
# 17894                  0                     1                       0
# 17895                  0                     1                       0
# 17896                  0                     1                       0
# 17897                  0                     1                       0
# 17898                  0                     1                       0
#
# [55100 rows x 3 columns]

# %%
dfD[dfD.columns[21:28]]
# Out:
#       neighbourhood                 neighbourhood_cleansed  \
# 35932      El Raval                               el Raval
# 35933      El Raval                               el Raval
# 35934      El Raval                               el Raval
# 35935      El Raval                               el Raval
# 35936      El Raval                               el Raval
# ...             ...                                    ...
# 17894  Ciutat Vella                         el Barri Gòtic
# 17895      El Gòtic                         el Barri Gòtic
# 17896      El Gòtic                         el Barri Gòtic
# 17897    Sant Martí          la Vila Olímpica del Poblenou
# 17898      El Gòtic  Sant Pere, Santa Caterina i la Ribera
#
#       neighbourhood_group_cleansed     market    smart_location   latitude  \
# 35932                 Ciutat Vella  Barcelona  Barcelona, Spain  41.379524
# 35933                 Ciutat Vella  Barcelona  Barcelona, Spain  41.380467
# 35934                 Ciutat Vella  Barcelona  Barcelona, Spain  41.380913
# 35935                 Ciutat Vella  Barcelona  Barcelona, Spain  41.380634
# 35936                 Ciutat Vella  Barcelona  Barcelona, Spain  41.380200
# ...                            ...        ...               ...        ...
# 17894                 Ciutat Vella  Barcelona  Barcelona, Spain  41.385480
# 17895                 Ciutat Vella  Barcelona  Barcelona, Spain  41.385480
# 17896                 Ciutat Vella  Barcelona  Barcelona, Spain  41.385480
# 17897                   Sant Martí  Barcelona  Barcelona, Spain  41.392230
# 17898                 Ciutat Vella  Barcelona  Barcelona, Spain  41.384450
#
#        longitude
# 35932   2.169293
# 35933   2.165994
# 35934   2.165201
# 35935   2.169947
# 35936   2.174031
# ...          ...
# 17894   2.172890
# 17895   2.172890
# 17896   2.172890
# 17897   2.199060
# 17898   2.180280
#
# [55100 rows x 7 columns]

# %%
dfD['market'].value_counts()
# Out:
# Barcelona                55021
# Other (International)       11
# Milan                        3
# Madrid                       3
# Costa Brava Nord             2
# Buenos Aires                 1
# Name: market, dtype: int64

# %%
dfD[dfD['market'] == 'Milan']['neighbourhood']
# Out:
# 51923    Camp d'en Grassot i Gràcia Nova
# 22207    Camp d'en Grassot i Gràcia Nova
# 4065                              Gràcia
# Name: neighbourhood, dtype: object

# %%
dfD['street'].value_counts()
# Out:
# Barcelona, Catalunya, Spain                    37682
# Barcelona, Catalonia, Spain                     7290
# Barcelona, Barcelona, Spain                     2750
# Barcelona, CT, Spain                            2561
# Barcelona, Spain                                1200
#                                                ...
# Barcelona, Catalunya, ES, Barcelons, Spain         1
# barcelona, comunidad de cataluña, Spain            1
# Santa Coloma de Gramenet, Barcelona, Spain         1
# Barcelona Sant Andreu de Palomar, ES, Spain        1
# Barcelona, Barcleona, Spain                        1
# Name: street, Length: 179, dtype: int64

# %%
dfD['smart_location'].value_counts()
# Out:
# Barcelona, Spain                           53274
# BARCELONA, Spain                             703
# L'Hospitalet de Llobregat, Spain             465
# Barcelona , Spain                             97
# barcelona, Spain                              79
#                                            ...
# San Adrián del Besós, Spain                    1
# Caldes de Montbui, Spain                       1
# Barcelona Sant Andreu de Palomar, Spain        1
# Molins de Rei, Spain                           1
# BARCELONA CLOT, Spain                          1
# Name: smart_location, Length: 71, dtype: int64

# %%
dropC = ['market', 'street', 'smart_location']
dfD.drop(dropC, axis = 1, inplace = True)

# %%
dfD[dfD.columns[28:35]].isnull().sum()
# Out:
# accommodates     0
# bathrooms       47
# bedrooms        17
# beds            87
# bed_type         0
# amenities        0
# price            0
# dtype: int64

# %%
dfD[dfD.columns[28:35]]
# Out:
#        accommodates  bathrooms  bedrooms  beds  bed_type  \
# 35932             4        1.0       1.0   4.0  Real Bed
# 35933             4        1.0       1.0   3.0  Real Bed
# 35934             4        2.0       2.0   2.0  Real Bed
# 35935             2        1.0       1.0   1.0  Real Bed
# 35936             2        1.5       1.0   1.0  Real Bed
# ...             ...        ...       ...   ...       ...
# 17894             9        2.5       4.0   4.0  Real Bed
# 17895             9        2.5       4.0   4.0  Real Bed
# 17896             9        2.5       4.0   4.0  Real Bed
# 17897             4        1.0       2.0   3.0  Real Bed
# 17898             2        2.0       1.0   1.0  Real Bed
#
#                                                amenities    price
# 35932  {TV,Wifi,"Air conditioning",Kitchen,"Hot tub",...   $80.00
# 35933  {Internet,Wifi,Kitchen,"Buzzer/wireless interc...   $70.00
# 35934  {TV,Internet,Wifi,"Air conditioning","Wheelcha...   $45.00
# 35935  {TV,Wifi,"Air conditioning",Kitchen,"Smoking a...   $75.00
# 35936  {Wifi,Kitchen,"Family/kid friendly",Washer,Dry...   $97.00
# ...                                                  ...      ...
# 17894  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  $210.00
# 17895  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  $210.00
# 17896  {TV,Wifi,"Air conditioning",Kitchen,"Free park...  $210.00
# 17897  {TV,Wifi,"Air conditioning",Kitchen,Heating,Wa...   $99.00
# 17898  {TV,Wifi,Kitchen,"Smoking allowed",Breakfast,E...   $50.00
#
# [55100 rows x 7 columns]

# %%
print('Hay', dfD['room_type'].isnull().sum(), 'nulls')
print('=' * 50)
dfD['room_type'].value_counts()
# Out:
# Hay 0 nulls
# ==================================================
# Private room       28044
# Entire home/apt    26499
# Shared room          557
# Name: room_type, dtype: int64

# %%
dfD[dfD['accommodates']==1].groupby('accommodates')['bathrooms'].median()
# Out:
# accommodates
# 1    1.0
# Name: bathrooms, dtype: float64

# %%
dfD[['accommodates', 'bathrooms', 'bedrooms', 'beds']].groupby('accommodates').median()
# Out:
#               bathrooms  bedrooms  beds
# accommodates
# 1                   1.0       1.0   1.0
# 2                   1.0       1.0   1.0
# 3                   1.0       1.0   2.0
# 4                   1.0       2.0   2.0
# 5                   1.0       2.0   3.0
# 6                   2.0       3.0   4.0
# 7                   2.0       3.0   5.0
# 8                   2.0       3.0   6.0
# 9                   2.0       4.0   7.0
# 10                  2.0       4.0   7.0
# 11                  2.0       4.0   8.0
# 12                  2.0       5.0  10.0
# 13                  3.0       5.0  10.0
# 14                  3.0       6.0  11.0
# 15                  3.0       6.0  11.0
# 16                  4.0       6.0  16.0

# %%
dfD[['accommodates', 'bathrooms', 'bedrooms', 'beds']].median()
# Out:
# accommodates    2.0
# bathrooms       1.0
# bedrooms        1.0
# beds            2.0
# dtype: float64

# %%
dfD[['accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type']].isnull().sum()
# Out:
# accommodates     0
# bathrooms       47
# bedrooms        17
# beds            87
# bed_type         0
# dtype: int64

# %%
dfD[dfD['beds'].isnull()].groupby('accommodates')[['bed_type']].count()/dfD[dfD['beds'].isnull()].shape[0]
# Out:
#               bed_type
# accommodates
# 1             0.298851
# 2             0.436782
# 3             0.068966
# 4             0.103448
# 6             0.034483
# 7             0.034483
# 9             0.011494
# 16            0.011494

# %%
for column in ['bathrooms', 'bedrooms', 'beds']:
    dfD[column].fillna(dfD[column].median(), inplace = True)

# %%
dfD[['accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type']].isnull().sum()
# Out:
# accommodates    0
# bathrooms       0
# bedrooms        0
# beds            0
# bed_type        0
# dtype: int64

# %%
dfD[['accommodates', 'bathrooms', 'bedrooms', 'beds']].groupby('accommodates').median()
# Out:
#               bathrooms  bedrooms  beds
# accommodates
# 1                   1.0       1.0   1.0
# 2                   1.0       1.0   1.0
# 3                   1.0       1.0   2.0
# 4                   1.0       2.0   2.0
# 5                   1.0       2.0   3.0
# 6                   2.0       3.0   4.0
# 7                   2.0       3.0   5.0
# 8                   2.0       3.0   6.0
# 9                   2.0       4.0   7.0
# 10                  2.0       4.0   7.0
# 11                  2.0       4.0   8.0
# 12                  2.0       5.0  10.0
# 13                  3.0       5.0  10.0
# 14                  3.0       6.0  11.0
# 15                  3.0       6.0  11.0
# 16                  4.0       6.0  16.0

# %%
dfD['price'] = dfD['price'].str.replace('$', '').str.replace(',','').astype('float')

# %%
amenities = dfD['amenities'].str.replace('{', '').str.replace('}', '').str.replace('"', '').str.split(",")
dict_amen= {}
for lista in amenities:[
    for elemento in lista:
        if elemento in dict_amen:
            dict_amen[elemento] += 1
        else:
            dict_amen[elemento] = 1

# %% [markdown]
# ### MÁS PARA DISCUTIR

# %%
ser_amen = pd.Series(dict_amen, index = dict_amen.keys())
(ser_amen[ser_amen>dfD.shape[0]*.15]/dfD.shape[0]).sort_values(ascending = False)
# Out:
# Wifi                                          0.970454
# Essentials                                    0.937858
# Kitchen                                       0.891543
# Hangers                                       0.795100
# Washer                                        0.775045
# Heating                                       0.766152
# Hair dryer                                    0.758693
# TV                                            0.710817
# Iron                                          0.703721
# Shampoo                                       0.626007
# Elevator                                      0.614065
# Air conditioning                              0.565064
# Hot water                                     0.554047
# Laptop friendly workspace                     0.552595
# Family/kid friendly                           0.466824
# Host greets you                               0.402704
# Refrigerator                                  0.349964
# Dishes and silverware                         0.336987
# Bed linens                                    0.329673
# Internet                                      0.323557
# Microwave                                     0.316770
# Coffee maker                                  0.300653
# Cooking basics                                0.291506
# Step-free access                              0.275971
# Oven                                          0.272486
# Buzzer/wireless intercom                      0.263956
# Smoking allowed                               0.258439
# Dryer                                         0.250799
# First aid kit                                 0.244664
# Stove                                         0.239546
# Long term stays allowed                       0.232940
# Paid parking off premises                     0.231670
# Luggage dropoff allowed                       0.204955
# Extra pillows and blankets                    0.200236
# Fire extinguisher                             0.192142
# Patio or balcony                              0.179492
# Paid parking on premises                      0.179056
# Lock on bedroom door                          0.170835
# Smoke detector                                0.166697
# translation missing: en.hosting_amenity_50    0.164737
# Dishwasher                                    0.164011
# dtype: float64

# %%
columnselection = ['Air conditioning', 'Family/kid friendly', 'Host greets you', 'Laptop friendly workspace', 'Paid parking off premises', 
                  'Patio or balcony', 'Luggage dropoff allowed', 'Long term stays allowed', 'Smoking allowed', 'Step-free access',
                  'Paid parking on premises']
for column in columnselection:
    dfD[column] = dfD['amenities'].apply(lambda x: 1 if column in x else 0)
dfD.drop('amenities', axis = 1, inplace = True)

# %%
dfD[columnselection].sum()/dfD.shape[0]
# Out:
# Air conditioning             0.565064
# Family/kid friendly          0.466824
# Host greets you              0.402704
# Laptop friendly workspace    0.552595
# Paid parking off premises    0.231670
# Patio or balcony             0.179492
# Luggage dropoff allowed      0.204955
# Long term stays allowed      0.232940
# Smoking allowed              0.258439
# Step-free access             0.107659
# Paid parking on premises     0.179056
# dtype: float64

# %%
dfD[dfD.columns[35:42]]
# Out:
#       cleaning_fee  guests_included extra_people  minimum_nights  \
# 35932          NaN                1        $0.00              31
# 35933       $40.00                2       $10.00              30
# 35934          NaN                3       $10.00              32
# 35935       $40.00                1        $5.00              31
# 35936       $10.00                2      $100.00              30
# ...            ...              ...          ...             ...
# 17894          NaN                1        $0.00               3
# 17895          NaN                1        $0.00               3
# 17896          NaN                1        $0.00               3
# 17897          NaN                1        $0.00              31
# 17898       $15.00                1       $10.00               4
#
#        maximum_nights calendar_updated has_availability
# 35932              90     3 months ago                t
# 35933            1125     3 months ago                t
# 35934             360       3 days ago                t
# 35935            1125      3 weeks ago                t
# 35936            1125      2 weeks ago                t
# ...               ...              ...              ...
# 17894            1125            today                t
# 17895            1125            today                t
# 17896            1125            today                t
# 17897            1125            today                t
# 17898            1125            today                t
#
# [55100 rows x 7 columns]

# %%
for column in ['security_deposit', 'cleaning_fee', 'extra_people']:
    dfD[column] = dfD[column].str.replace('$', '').str.replace(',','').astype('float')
    dfD[column].fillna(0, inplace = True)

# %%
dfD[dfD.columns[35:42]]
# Out:
#        cleaning_fee  guests_included  extra_people  minimum_nights  \
# 35932           0.0                1           0.0              31
# 35933          40.0                2          10.0              30
# 35934           0.0                3          10.0              32
# 35935          40.0                1           5.0              31
# 35936          10.0                2         100.0              30
# ...             ...              ...           ...             ...
# 17894           0.0                1           0.0               3
# 17895           0.0                1           0.0               3
# 17896           0.0                1           0.0               3
# 17897           0.0                1           0.0              31
# 17898          15.0                1          10.0               4
#
#        maximum_nights calendar_updated has_availability
# 35932              90     3 months ago                t
# 35933            1125     3 months ago                t
# 35934             360       3 days ago                t
# 35935            1125      3 weeks ago                t
# 35936            1125      2 weeks ago                t
# ...               ...              ...              ...
# 17894            1125            today                t
# 17895            1125            today                t
# 17896            1125            today                t
# 17897            1125            today                t
# 17898            1125            today                t
#
# [55100 rows x 7 columns]

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'neighborhood_overview', 'transit', 'access',
#        'interaction', 'house_rules', 'host_id', 'host_since', 'host_location',
#        'host_response_time', 'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'calendar_updated',
#        'has_availability', 'availability_30', 'availability_60',
#        'availability_90', 'availability_365', 'calendar_last_scraped',
#        'number_of_reviews', 'number_of_reviews_ltm', 'first_review',
#        'last_review', 'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month', 'host_emailverified', 'host_phoneverified',
#        'host_hasjumio', 'host_reviewverified', 'host_selfieverified',
#        'Air conditioning', 'Family/kid friendly', 'Host greets you',
#        'Laptop friendly workspace', 'Paid parking off premises',
#        'Patio or balcony', 'Luggage dropoff allowed',
#        'Long term stays allowed', 'Smoking allowed', 'Step-free access',
#        'Paid parking on premises'],
#       dtype='object')

# %%
dfD[dfD.columns[42:49]]
# Out:
#        availability_30  availability_60  availability_90  availability_365  \
# 35932               30               60               90               180
# 35933                0                0                0               254
# 35934                0                0                0                85
# 35935               13               43               73               189
# 35936                5               35               39               310
# ...                ...              ...              ...               ...
# 17894               29               59               89               364
# 17895               29               59               89               361
# 17896               29               56               86               361
# 17897                1                9               39               220
# 17898               15               15               15                15
#
#       calendar_last_scraped  number_of_reviews  number_of_reviews_ltm
# 35932            2018-04-12                 18                    NaN
# 35933            2018-04-12                  6                    NaN
# 35934            2018-04-12                  2                    NaN
# 35935            2018-04-12                  2                    NaN
# 35936            2018-04-12                  7                    NaN
# ...                     ...                ...                    ...
# 17894            2019-04-10                  0                    0.0
# 17895            2019-04-10                  0                    0.0
# 17896            2019-04-10                  0                    0.0
# 17897            2019-04-10                  0                    0.0
# 17898            2019-04-10                  0                    0.0
#
# [55100 rows x 7 columns]

# %%
dfD['availability_365'].isnull().sum()
# Out:
# 0

# %%
dfD['availability_365'].value_counts()
# Out:
# 0      7976
# 365    1505
# 364    1030
# 89      453
# 90      356
#        ...
# 108      56
# 182      52
# 118      52
# 111      52
# 117      51
# Name: availability_365, Length: 366, dtype: int64

# %%
dropC = ['has_availability', 'availability_30', 'availability_60', 'availability_90']
dfD.drop(dropC, axis = 1, inplace = True)

# %%
dfD[dfD['availability_365']<100]['availability_365'].value_counts()
# Out:
# 0     7976
# 89     453
# 90     356
# 1      243
# 88     193
#       ...
# 94      65
# 92      64
# 97      63
# 26      59
# 93      58
# Name: availability_365, Length: 100, dtype: int64

# %%
dfD[dfD.columns[44:56]]
# Out:
#        number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 35932                    NaN   2015-10-03  2017-10-20                  85.0
# 35933                    NaN   2016-04-30  2017-11-01                  93.0
# 35934                    NaN   2016-08-20  2016-11-11                  90.0
# 35935                    NaN   2017-06-26  2017-12-23                 100.0
# 35936                    NaN   2017-09-22  2018-01-23                  97.0
# ...                      ...          ...         ...                   ...
# 17894                    0.0          NaN         NaN                   NaN
# 17895                    0.0          NaN         NaN                   NaN
# 17896                    0.0          NaN         NaN                   NaN
# 17897                    0.0          NaN         NaN                   NaN
# 17898                    0.0          NaN         NaN                   NaN
#
#        review_scores_accuracy  review_scores_cleanliness  \
# 35932                     9.0                        7.0
# 35933                     9.0                        9.0
# 35934                    10.0                       10.0
# 35935                     9.0                        9.0
# 35936                    10.0                       10.0
# ...                       ...                        ...
# 17894                     NaN                        NaN
# 17895                     NaN                        NaN
# 17896                     NaN                        NaN
# 17897                     NaN                        NaN
# 17898                     NaN                        NaN
#
#        review_scores_checkin  review_scores_communication  \
# 35932                   10.0                         10.0
# 35933                   10.0                         10.0
# 35934                   10.0                         10.0
# 35935                   10.0                         10.0
# 35936                   10.0                         10.0
# ...                      ...                          ...
# 17894                    NaN                          NaN
# 17895                    NaN                          NaN
# 17896                    NaN                          NaN
# 17897                    NaN                          NaN
# 17898                    NaN                          NaN
#
#        review_scores_location  review_scores_value requires_license  \
# 35932                     9.0                  9.0                t
# 35933                    10.0                  9.0                t
# 35934                    10.0                  6.0                t
# 35935                    10.0                 10.0                t
# 35936                    10.0                  9.0                t
# ...                       ...                  ...              ...
# 17894                     NaN                  NaN                t
# 17895                     NaN                  NaN                t
# 17896                     NaN                  NaN                t
# 17897                     NaN                  NaN                t
# 17898                     NaN                  NaN                t
#
#       instant_bookable
# 35932                t
# 35933                f
# 35934                f
# 35935                f
# 35936                t
# ...                ...
# 17894                f
# 17895                f
# 17896                f
# 17897                f
# 17898                f
#
# [55100 rows x 12 columns]

# %%
dfD['review_scores_checkin'].isnull().sum()
# Out:
# 12075

# %%
dfD[dfD.columns[56:63]]
# Out:
#       is_business_travel_ready          cancellation_policy  \
# 35932                        f                     moderate
# 35933                        f                       strict
# 35934                        f                       strict
# 35935                        f                       strict
# 35936                        f                       strict
# ...                        ...                          ...
# 17894                        f                     flexible
# 17895                        f                     flexible
# 17896                        f                     flexible
# 17897                        f  strict_14_with_grace_period
# 17898                        f                     flexible
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 35932                             f                                f
# 35933                             f                                f
# 35934                             f                                f
# 35935                             f                                f
# 35936                             f                                f
# ...                             ...                              ...
# 17894                             f                                f
# 17895                             f                                f
# 17896                             f                                f
# 17897                             f                                f
# 17898                             f                                f
#
#        calculated_host_listings_count  \
# 35932                               8
# 35933                               1
# 35934                              11
# 35935                               1
# 35936                               8
# ...                               ...
# 17894                               3
# 17895                               3
# 17896                               3
# 17897                               1
# 17898                               2
#
#        calculated_host_listings_count_entire_homes  \
# 35932                                          NaN
# 35933                                          NaN
# 35934                                          NaN
# 35935                                          NaN
# 35936                                          NaN
# ...                                            ...
# 17894                                          3.0
# 17895                                          3.0
# 17896                                          3.0
# 17897                                          1.0
# 17898                                          0.0
#
#        calculated_host_listings_count_private_rooms
# 35932                                           NaN
# 35933                                           NaN
# 35934                                           NaN
# 35935                                           NaN
# 35936                                           NaN
# ...                                             ...
# 17894                                           0.0
# 17895                                           0.0
# 17896                                           0.0
# 17897                                           0.0
# 17898                                           2.0
#
# [55100 rows x 7 columns]

# %%
dfD['cancellation_policy'].value_counts()
# Out:
# strict_14_with_grace_period    17870
# moderate                       14092
# flexible                       13938
# strict                          8500
# super_strict_30                  665
# super_strict_60                   35
# Name: cancellation_policy, dtype: int64

# %%
cancelpol = {'strict_14_with_grace_period': 'strict_less30', 'flexible':'flexible', 'moderate':'moderate', 'super_strict_30':'strict_30orMore',
           'super_strict_60':'strict_30orMore', 'strict':'strict_less30'}
dfD['cancellation_policy'] = dfD['cancellation_policy'].map(cancelpol)

# %% [markdown]
# strict_below_14 = dfD[dfD['cancellation_policy'] == 'strict_14_with_grace_period']
# strict_above_14 = dfD[dfD['cancellation_policy'] == 'strict_14_with_grace_period']
# for elemento in dfD['cancellation_policy']:
#     if elemento == 'strict_14_with_grace_period':
#         strict_below_14

# %%
dfD['cancellation_policy'].value_counts()
# Out:
# strict_less30      26370
# moderate           14092
# flexible           13938
# strict_30orMore      700
# Name: cancellation_policy, dtype: int64

# %% [markdown]
# **host_response_rate**
#
# **review_scores_rating**
#
# **review_scores_accuracy**
#
# **review_scores_cleanliness**
#
# **review_scores_checkin**
#
# **review_scores_communication**
#
# **review_scores_location**
#
# **review_scores_value**
#
# Cambiar por -1 los valores nulls y añadir una dummy column con valor 1 o 0 si se ha imputado el valor null

# %%
dfD[dfD.columns[48:56]].isnull().sum()
# Out:
# review_scores_accuracy         12050
# review_scores_cleanliness      12045
# review_scores_checkin          12075
# review_scores_communication    12041
# review_scores_location         12078
# review_scores_value            12077
# requires_license                   0
# instant_bookable                   0
# dtype: int64

# %%
dfD.columns.str.startswith('review')
# Out:
# array([False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False, False, False, False, False, False, False,
#        False,  True, False, False, False, False, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False])

# %%
dfD[dfD['last_review'].isnull()][dfD.columns[dfD.columns.str.startswith('review')]].sample(20)
# Out:
#        review_scores_rating  review_scores_accuracy  \
# 35816                   NaN                     NaN
# 7216                    NaN                     NaN
# 35003                   NaN                     NaN
# 12732                   NaN                     NaN
# 16942                   NaN                     NaN
# 42999                   NaN                     NaN
# 50377                   NaN                     NaN
# 25070                   NaN                     NaN
# 8816                    NaN                     NaN
# 16983                   NaN                     NaN
# 1548                    NaN                     NaN
# 46479                   NaN                     NaN
# 30944                   NaN                     NaN
# 17476                   NaN                     NaN
# 45046                   NaN                     NaN
# 33010                   NaN                     NaN
# 12523                   NaN                     NaN
# 15950                   NaN                     NaN
# 43025                   NaN                     NaN
# 54680                   NaN                     NaN
#
#        review_scores_cleanliness  review_scores_checkin  \
# 35816                        NaN                    NaN
# 7216                         NaN                    NaN
# 35003                        NaN                    NaN
# 12732                        NaN                    NaN
# 16942                        NaN                    NaN
# 42999                        NaN                    NaN
# 50377                        NaN                    NaN
# 25070                        NaN                    NaN
# 8816                         NaN                    NaN
# 16983                        NaN                    NaN
# 1548                         NaN                    NaN
# 46479                        NaN                    NaN
# 30944                        NaN                    NaN
# 17476                        NaN                    NaN
# 45046                        NaN                    NaN
# 33010                        NaN                    NaN
# 12523                        NaN                    NaN
# 15950                        NaN                    NaN
# 43025                        NaN                    NaN
# 54680                        NaN                    NaN
#
#        review_scores_communication  review_scores_location  \
# 35816                          NaN                     NaN
# 7216                           NaN                     NaN
# 35003                          NaN                     NaN
# 12732                          NaN                     NaN
# 16942                          NaN                     NaN
# 42999                          NaN                     NaN
# 50377                          NaN                     NaN
# 25070                          NaN                     NaN
# 8816                           NaN                     NaN
# 16983                          NaN                     NaN
# 1548                           NaN                     NaN
# 46479                          NaN                     NaN
# 30944                          NaN                     NaN
# 17476                          NaN                     NaN
# 45046                          NaN                     NaN
# 33010                          NaN                     NaN
# 12523                          NaN                     NaN
# 15950                          NaN                     NaN
# 43025                          NaN                     NaN
# 54680                          NaN                     NaN
#
#        review_scores_value  reviews_per_month
# 35816                  NaN                NaN
# 7216                   NaN                NaN
# 35003                  NaN                NaN
# 12732                  NaN                NaN
# 16942                  NaN                NaN
# 42999                  NaN                NaN
# 50377                  NaN                NaN
# 25070                  NaN                NaN
# 8816                   NaN                NaN
# 16983                  NaN                NaN
# 1548                   NaN                NaN
# 46479                  NaN                NaN
# 30944                  NaN                NaN
# 17476                  NaN                NaN
# 45046                  NaN                NaN
# 33010                  NaN                NaN
# 12523                  NaN                NaN
# 15950                  NaN                NaN
# 43025                  NaN                NaN
# 54680                  NaN                NaN

# %%
dfD[dfD['review_scores_accuracy'].isnull()]['year'].value_counts()
# Out:
# 2019    8329
# 2018    3721
# Name: year, dtype: int64

# %%
dfD[dfD['last_review'].isnull()].groupby(['year', 'month']).count()[dfD.columns[dfD.columns.str.startswith('review')]]
# Out:
#             review_scores_rating  review_scores_accuracy  \
# year month
# 2018 04                        2                       2
# 2019 01                        0                       0
#      04                        0                       0
#
#             review_scores_cleanliness  review_scores_checkin  \
# year month
# 2018 04                             2                      2
# 2019 01                             0                      0
#      04                             0                      0
#
#             review_scores_communication  review_scores_location  \
# year month
# 2018 04                               2                       2
# 2019 01                               0                       0
#      04                               0                       0
#
#             review_scores_value  reviews_per_month
# year month
# 2018 04                       2                  0
# 2019 01                       0                  0
#      04                       0                  0

# %%
dfD['last_review'].isnull().sum()
# Out:
# 11292

# %%
dfD[dfD['last_review'].isnull()][dfD.columns[dfD.columns.str.startswith('review')]].isnull().sum()
# Out:
# review_scores_rating           11290
# review_scores_accuracy         11290
# review_scores_cleanliness      11290
# review_scores_checkin          11290
# review_scores_communication    11290
# review_scores_location         11290
# review_scores_value            11290
# reviews_per_month              11292
# dtype: int64

# %%
dfD.dropna(subset = ['last_review'], inplace = True)

# %%
dfD[dfD.columns[dfD.columns.str.startswith('review')]].isnull().sum()
# Out:
# review_scores_rating           729
# review_scores_accuracy         760
# review_scores_cleanliness      755
# review_scores_checkin          785
# review_scores_communication    751
# review_scores_location         788
# review_scores_value            787
# reviews_per_month               13
# dtype: int64

# %%
dfD[dfD['review_scores_location'].isnull()][dfD.columns[dfD.columns.str.startswith('review')]].isnull().sum()
# Out:
# review_scores_rating           722
# review_scores_accuracy         745
# review_scores_cleanliness      741
# review_scores_checkin          774
# review_scores_communication    747
# review_scores_location         788
# review_scores_value            783
# reviews_per_month               13
# dtype: int64

# %%
dfD[dfD['review_scores_location'].isnull()].groupby(['year', 'month']).count()[dfD.columns[dfD.columns.str.startswith('review')]]
# Out:
#             review_scores_rating  review_scores_accuracy  \
# year month
# 2018 04                       34                      21
# 2019 01                       18                      12
#      04                       14                      10
#
#             review_scores_cleanliness  review_scores_checkin  \
# year month
# 2018 04                            23                      6
# 2019 01                            13                      4
#      04                            11                      4
#
#             review_scores_communication  review_scores_location  \
# year month
# 2018 04                              19                       0
# 2019 01                              12                       0
#      04                              10                       0
#
#             review_scores_value  reviews_per_month
# year month
# 2018 04                       3                323
# 2019 01                       1                228
#      04                       1                224

# %%
dfD.dropna(subset = ['review_scores_location'], inplace = True)

# %%
dfD[dfD.columns[dfD.columns.str.startswith('review')]].isnull().sum()
# Out:
# review_scores_rating            7
# review_scores_accuracy         15
# review_scores_cleanliness      14
# review_scores_checkin          11
# review_scores_communication     4
# review_scores_location          0
# review_scores_value             4
# reviews_per_month               0
# dtype: int64

# %%
dfD[dfD.columns[dfD.columns.str.startswith('review')]].describe()
# Out:
#        review_scores_rating  review_scores_accuracy  \
# count          43013.000000            43005.000000
# mean              91.052937                9.375840
# std                9.232556                0.935834
# min               20.000000                2.000000
# 25%               88.000000                9.000000
# 50%               93.000000               10.000000
# 75%               97.000000               10.000000
# max              100.000000               10.000000
#
#        review_scores_cleanliness  review_scores_checkin  \
# count               43006.000000           43009.000000
# mean                    9.239990               9.580460
# std                     1.041518               0.837302
# min                     2.000000               2.000000
# 25%                     9.000000               9.000000
# 50%                     9.000000              10.000000
# 75%                    10.000000              10.000000
# max                    10.000000              10.000000
#
#        review_scores_communication  review_scores_location  \
# count                 43016.000000            43020.000000
# mean                      9.569370                9.521176
# std                       0.844576                0.763173
# min                       2.000000                2.000000
# 25%                       9.000000                9.000000
# 50%                      10.000000               10.000000
# 75%                      10.000000               10.000000
# max                      10.000000               10.000000
#
#        review_scores_value  reviews_per_month
# count         43016.000000       43020.000000
# mean              9.054468           1.646541
# std               0.988077           1.630302
# min               2.000000           0.010000
# 25%               9.000000           0.430000
# 50%               9.000000           1.130000
# 75%              10.000000           2.430000
# max              10.000000          96.600000

# %%
dfD['review_scores_rating'] = dfD['review_scores_rating']/10

# %%
for column in dfD.columns[dfD.columns.str.startswith('review')]:
    dfD.dropna(subset = [column], inplace = True)

# %%
dfD[dfD.columns[dfD.columns.str.startswith('review')]].isnull().sum()
# Out:
# review_scores_rating           0
# review_scores_accuracy         0
# review_scores_cleanliness      0
# review_scores_checkin          0
# review_scores_communication    0
# review_scores_location         0
# review_scores_value            0
# reviews_per_month              0
# dtype: int64

# %%
dfD[dfD.columns[56:63]]
# Out:
#       is_business_travel_ready cancellation_policy  \
# 35932                        f            moderate
# 35933                        f       strict_less30
# 35934                        f       strict_less30
# 35935                        f       strict_less30
# 35936                        f       strict_less30
# ...                        ...                 ...
# 17643                        f            flexible
# 17687                        f       strict_less30
# 17688                        f            moderate
# 17715                        f       strict_less30
# 17733                        f            moderate
#
#       require_guest_profile_picture require_guest_phone_verification  \
# 35932                             f                                f
# 35933                             f                                f
# 35934                             f                                f
# 35935                             f                                f
# 35936                             f                                f
# ...                             ...                              ...
# 17643                             f                                f
# 17687                             f                                f
# 17688                             f                                f
# 17715                             f                                f
# 17733                             f                                f
#
#        calculated_host_listings_count  \
# 35932                               8
# 35933                               1
# 35934                              11
# 35935                               1
# 35936                               8
# ...                               ...
# 17643                               1
# 17687                               1
# 17688                               1
# 17715                               1
# 17733                               1
#
#        calculated_host_listings_count_entire_homes  \
# 35932                                          NaN
# 35933                                          NaN
# 35934                                          NaN
# 35935                                          NaN
# 35936                                          NaN
# ...                                            ...
# 17643                                          1.0
# 17687                                          0.0
# 17688                                          0.0
# 17715                                          1.0
# 17733                                          0.0
#
#        calculated_host_listings_count_private_rooms
# 35932                                           NaN
# 35933                                           NaN
# 35934                                           NaN
# 35935                                           NaN
# 35936                                           NaN
# ...                                             ...
# 17643                                           0.0
# 17687                                           1.0
# 17688                                           1.0
# 17715                                           0.0
# 17733                                           1.0
#
# [42990 rows x 7 columns]

# %%
dfD[dfD.columns[56:63]].isnull().sum()
# Out:
# is_business_travel_ready                            0
# cancellation_policy                                 0
# require_guest_profile_picture                       0
# require_guest_phone_verification                    0
# calculated_host_listings_count                      0
# calculated_host_listings_count_entire_homes     15414
# calculated_host_listings_count_private_rooms    15414
# dtype: int64

# %%
dfD[dfD.columns[63:68]]
# Out:
#        calculated_host_listings_count_shared_rooms  reviews_per_month  year  \
# 35932                                          NaN               0.59  2018
# 35933                                          NaN               0.25  2018
# 35934                                          NaN               0.10  2018
# 35935                                          NaN               0.21  2018
# 35936                                          NaN               1.03  2018
# ...                                            ...                ...   ...
# 17643                                          0.0               1.00  2019
# 17687                                          0.0               1.00  2019
# 17688                                          0.0               1.00  2019
# 17715                                          0.0               1.00  2019
# 17733                                          0.0               1.00  2019
#
#       month  host_emailverified
# 35932    04                   1
# 35933    04                   1
# 35934    04                   1
# 35935    04                   1
# 35936    04                   1
# ...     ...                 ...
# 17643    04                   1
# 17687    04                   1
# 17688    04                   1
# 17715    04                   1
# 17733    04                   0
#
# [42990 rows x 5 columns]

# %%
dfD[dfD.columns[63:68]].isnull().sum()
# Out:
# calculated_host_listings_count_shared_rooms    15414
# reviews_per_month                                  0
# year                                               0
# month                                              0
# host_emailverified                                 0
# dtype: int64

# %%
dfD.columns[68:]
# Out:
# Index(['host_phoneverified', 'host_hasjumio', 'host_reviewverified',
#        'host_selfieverified', 'Air conditioning', 'Family/kid friendly',
#        'Host greets you', 'Laptop friendly workspace',
#        'Paid parking off premises', 'Patio or balcony',
#        'Luggage dropoff allowed', 'Long term stays allowed', 'Smoking allowed',
#        'Step-free access', 'Paid parking on premises'],
#       dtype='object')

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'last_scraped', 'name', 'summary', 'space',
#        'description', 'neighborhood_overview', 'transit', 'access',
#        'interaction', 'house_rules', 'host_id', 'host_since', 'host_location',
#        'host_response_time', 'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'neighbourhood',
#        'neighbourhood_cleansed', 'neighbourhood_group_cleansed', 'latitude',
#        'longitude', 'is_location_exact', 'property_type', 'room_type',
#        'accommodates', 'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'calendar_updated',
#        'availability_365', 'calendar_last_scraped', 'number_of_reviews',
#        'number_of_reviews_ltm', 'first_review', 'last_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month', 'host_emailverified', 'host_phoneverified',
#        'host_hasjumio', 'host_reviewverified', 'host_selfieverified',
#        'Air conditioning', 'Family/kid friendly', 'Host greets you',
#        'Laptop friendly workspace', 'Paid parking off premises',
#        'Patio or balcony', 'Luggage dropoff allowed',
#        'Long term stays allowed', 'Smoking allowed', 'Step-free access',
#        'Paid parking on premises'],
#       dtype='object')

# %%
dfD['is_location_exact']
# Out:
# 35932    t
# 35933    f
# 35934    f
# 35935    f
# 35936    t
#         ..
# 17643    t
# 17687    f
# 17688    f
# 17715    t
# 17733    t
# Name: is_location_exact, Length: 42990, dtype: object

# %%
dfD.dtypes[dfD.dtypes == 'O']
# Out:
# last_scraped                        object
# name                                object
# summary                             object
# space                               object
# description                         object
# neighborhood_overview               object
# transit                             object
# access                              object
# interaction                         object
# house_rules                         object
# host_since                          object
# host_location                       object
# host_response_time                  object
# neighbourhood                       object
# neighbourhood_cleansed              object
# neighbourhood_group_cleansed        object
# is_location_exact                   object
# property_type                       object
# room_type                           object
# bed_type                            object
# calendar_updated                    object
# calendar_last_scraped               object
# first_review                        object
# last_review                         object
# requires_license                    object
# instant_bookable                    object
# is_business_travel_ready            object
# cancellation_policy                 object
# require_guest_profile_picture       object
# require_guest_phone_verification    object
# year                                object
# month                               object
# dtype: object

# %%
dfD['bed_type'].isnull().sum()
# Out:
# 0

# %%
dropC = ['calendar_updated', 'calendar_last_scraped', 'host_location', 'last_review', 'last_scraped', 
         'neighbourhood', 'neighbourhood_cleansed']
dfD.drop(dropC, axis = 1, inplace = True)

# %%
dfD['host_since'].isnull().sum()
# Out:
# 29

# %%
dfD.dropna(subset = ['host_since'], inplace = True)

# %%
dfD['house_rules'].isnull().sum()/dfD.shape[0]
# Out:
# 0.28563115383720117

# %%
dfD['interaction'].isnull().sum()/dfD.shape[0]
# Out:
# 0.3990596122064198

# %%
dfD['name'].isnull().sum()
# Out:
# 29

# %%
for element in dfD['property_type']:
    if element in ['House', 'Casa', 'Chalet', 'house']:
        element = 'house'
    elif element in ['Hotel', 'Serviced apartment', 'Aparthotel']:
        element = 'hotel'
    elif element in ['Hostel', 'Bed and breakfast']:
        element = 'hostel'
    elif element in ['Apartment', 'Loft']:
        element = 'apartment'
    else:
        element = 'other'

# %%
dfD['property_type'].map({'Apartment': 'apartment'})
# Out:
# 35932    apartment
# 35933    apartment
# 35934    apartment
# 35935    apartment
# 35936    apartment
#            ...
# 17643          NaN
# 17687    apartment
# 17688    apartment
# 17715    apartment
# 17733          NaN
# Name: property_type, Length: 42961, dtype: object

# %%
dfD['property_type'].value_counts()
# Out:
# Apartment                 36863
# Serviced apartment         1415
# Loft                       1056
# House                       820
# Condominium                 712
# Bed and breakfast           510
# Guest suite                 399
# Other                       271
# Hostel                      208
# Boat                        140
# Boutique hotel              114
# Guesthouse                  108
# Townhouse                    82
# Casa particular (Cuba)       58
# Aparthotel                   47
# Villa                        40
# Dorm                         34
# Hotel                        20
# Tiny house                   12
# In-law                       10
# Vacation home                 9
# Camper/RV                     8
# Chalet                        5
# Cabin                         3
# Cave                          3
# Farm stay                     2
# Cottage                       2
# Dome house                    2
# Train                         1
# Bungalow                      1
# Barn                          1
# Castle                        1
# Houseboat                     1
# Casa particular               1
# Plane                         1
# Earth house                   1
# Name: property_type, dtype: int64

# %%
new_cat = {'Apartment':'apartment', 'Service apartment': 'hotel', 'Loft': 'apartment', 'House':'house', 'Condominium':'house',
          'Bed and breakfast':'hostel', 'Guest suite':'hotel', 'Hostel':'hostel', 'Boutique hotel':'hotel', 'Boat':'boat', 'Guest House':'hostel',
          'Hotel':'hotel', 'Townhouse':'house', 'Aparthotel':'hotel', 'Casa particular (Cuba)':'house', 'Villa':'villa', 'Chalet':'house', 
          'Houseboat':'boat', 'Resort':'hotel'}
dfD['property_type'] = dfD['property_type'].map(new_cat).fillna('other')

# %%
dfD['property_type'].value_counts()
# Out:
# apartment    37919
# other         1886
# house         1677
# hostel         718
# hotel          580
# boat           141
# villa           40
# Name: property_type, dtype: int64

# %%
dfD.columns
# Out:
# Index(['id', 'scrape_id', 'name', 'summary', 'space', 'description',
#        'neighborhood_overview', 'transit', 'access', 'interaction',
#        'house_rules', 'host_id', 'host_since', 'host_response_time',
#        'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified',
#        'neighbourhood_group_cleansed', 'latitude', 'longitude',
#        'is_location_exact', 'property_type', 'room_type', 'accommodates',
#        'bathrooms', 'bedrooms', 'beds', 'bed_type', 'price',
#        'security_deposit', 'cleaning_fee', 'guests_included', 'extra_people',
#        'minimum_nights', 'maximum_nights', 'availability_365',
#        'number_of_reviews', 'number_of_reviews_ltm', 'first_review',
#        'review_scores_rating', 'review_scores_accuracy',
#        'review_scores_cleanliness', 'review_scores_checkin',
#        'review_scores_communication', 'review_scores_location',
#        'review_scores_value', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count',
#        'calculated_host_listings_count_entire_homes',
#        'calculated_host_listings_count_private_rooms',
#        'calculated_host_listings_count_shared_rooms', 'reviews_per_month',
#        'year', 'month', 'host_emailverified', 'host_phoneverified',
#        'host_hasjumio', 'host_reviewverified', 'host_selfieverified',
#        'Air conditioning', 'Family/kid friendly', 'Host greets you',
#        'Laptop friendly workspace', 'Paid parking off premises',
#        'Patio or balcony', 'Luggage dropoff allowed',
#        'Long term stays allowed', 'Smoking allowed', 'Step-free access',
#        'Paid parking on premises'],
#       dtype='object')

# %%
dfD.drop('scrape_id', axis = 1, inplace = True)

# %%
dfD.isnull().sum()[dfD.isnull().sum() > 0]
# Out:
# name                                               29
# summary                                          1469
# space                                            9432
# description                                       199
# neighborhood_overview                           13683
# transit                                         15001
# access                                          16511
# interaction                                     17144
# house_rules                                     12271
# number_of_reviews_ltm                           15391
# calculated_host_listings_count_entire_homes     15391
# calculated_host_listings_count_private_rooms    15391
# calculated_host_listings_count_shared_rooms     15391
# dtype: int64

# %%
dfD.drop(['calculated_host_listings_count_entire_homes', 'calculated_host_listings_count_private_rooms', 
          'calculated_host_listings_count_shared_rooms','number_of_reviews_ltm'], axis = 1, inplace = True)

# %%
dfD['room_type'].value_counts()
# Out:
# Private room       21862
# Entire home/apt    20744
# Shared room          355
# Name: room_type, dtype: int64

# %%
dfD.isnull().sum()[dfD.isnull().sum()>0]
# Out:
# name                        29
# summary                   1469
# space                     9432
# description                199
# neighborhood_overview    13683
# transit                  15001
# access                   16511
# interaction              17144
# house_rules              12271
# dtype: int64

# %%
dfD.dtypes[dfD.isnull().sum()>0]
# Out:
# name                     object
# summary                  object
# space                    object
# description              object
# neighborhood_overview    object
# transit                  object
# access                   object
# interaction              object
# house_rules              object
# dtype: object

# %%
strCol = dfD.columns[dfD.dtypes == "object"]
noStrCol = dfD.columns[dfD.dtypes != "object"]

# %%
len(strCol), len(noStrCol)
# Out:
# (25, 46)

# %%
strCol
# Out:
# Index(['name', 'summary', 'space', 'description', 'neighborhood_overview',
#        'transit', 'access', 'interaction', 'house_rules', 'host_since',
#        'host_response_time', 'neighbourhood_group_cleansed',
#        'is_location_exact', 'property_type', 'room_type', 'bed_type',
#        'first_review', 'requires_license', 'instant_bookable',
#        'is_business_travel_ready', 'cancellation_policy',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'year', 'month'],
#       dtype='object')

# %%
dfD[['instant_bookable', 'is_business_travel_ready', 'is_location_exact', 'require_guest_phone_verification',
    'require_guest_profile_picture', 'requires_license']]
# Out:
#       instant_bookable is_business_travel_ready is_location_exact  \
# 35932                t                        f                 t
# 35933                f                        f                 f
# 35934                f                        f                 f
# 35935                f                        f                 f
# 35936                t                        f                 t
# ...                ...                      ...               ...
# 17643                f                        f                 t
# 17687                t                        f                 f
# 17688                f                        f                 f
# 17715                f                        f                 t
# 17733                t                        f                 t
#
#       require_guest_phone_verification require_guest_profile_picture  \
# 35932                                f                             f
# 35933                                f                             f
# 35934                                f                             f
# 35935                                f                             f
# 35936                                f                             f
# ...                                ...                           ...
# 17643                                f                             f
# 17687                                f                             f
# 17688                                f                             f
# 17715                                f                             f
# 17733                                f                             f
#
#       requires_license
# 35932                t
# 35933                t
# 35934                t
# 35935                t
# 35936                t
# ...                ...
# 17643                t
# 17687                t
# 17688                t
# 17715                t
# 17733                t
#
# [42961 rows x 6 columns]

# %%
dicotmicol = ['instant_bookable', 'is_business_travel_ready', 'is_location_exact', 'require_guest_phone_verification',
    'require_guest_profile_picture', 'requires_license']
for column in dicotmicol:
    dfD[column] = dfD[column].apply(lambda x: 1 if x=='t' else 0)

# %%
dfD[['instant_bookable', 'is_business_travel_ready', 'is_location_exact', 'require_guest_phone_verification',
    'require_guest_profile_picture', 'requires_license']]
# Out:
#        instant_bookable  is_business_travel_ready  is_location_exact  \
# 35932                 1                         0                  1
# 35933                 0                         0                  0
# 35934                 0                         0                  0
# 35935                 0                         0                  0
# 35936                 1                         0                  1
# ...                 ...                       ...                ...
# 17643                 0                         0                  1
# 17687                 1                         0                  0
# 17688                 0                         0                  0
# 17715                 0                         0                  1
# 17733                 1                         0                  1
#
#        require_guest_phone_verification  require_guest_profile_picture  \
# 35932                                 0                              0
# 35933                                 0                              0
# 35934                                 0                              0
# 35935                                 0                              0
# 35936                                 0                              0
# ...                                 ...                            ...
# 17643                                 0                              0
# 17687                                 0                              0
# 17688                                 0                              0
# 17715                                 0                              0
# 17733                                 0                              0
#
#        requires_license
# 35932                 1
# 35933                 1
# 35934                 1
# 35935                 1
# 35936                 1
# ...                 ...
# 17643                 1
# 17687                 1
# 17688                 1
# 17715                 1
# 17733                 1
#
# [42961 rows x 6 columns]

# %%
dfD[['instant_bookable', 'is_business_travel_ready', 'is_location_exact', 'require_guest_phone_verification',
    'require_guest_profile_picture', 'requires_license']].sum()/dfD.shape[0]
# Out:
# instant_bookable                    0.545378
# is_business_travel_ready            0.009916
# is_location_exact                   0.676893
# require_guest_phone_verification    0.044040
# require_guest_profile_picture       0.018715
# requires_license                    1.000000
# dtype: float64

# %%
strCol = dfD.columns[dfD.dtypes == "object"]
noStrCol = dfD.columns[dfD.dtypes != "object"]

# %%
strCol
# Out:
# Index(['name', 'summary', 'space', 'description', 'neighborhood_overview',
#        'transit', 'access', 'interaction', 'house_rules', 'host_since',
#        'host_response_time', 'neighbourhood_group_cleansed', 'property_type',
#        'room_type', 'bed_type', 'first_review', 'cancellation_policy', 'year',
#        'month'],
#       dtype='object')

# %%
noStrCol
# Out:
# Index(['id', 'host_id', 'host_is_superhost', 'host_total_listings_count',
#        'host_has_profile_pic', 'host_identity_verified', 'latitude',
#        'longitude', 'is_location_exact', 'accommodates', 'bathrooms',
#        'bedrooms', 'beds', 'price', 'security_deposit', 'cleaning_fee',
#        'guests_included', 'extra_people', 'minimum_nights', 'maximum_nights',
#        'availability_365', 'number_of_reviews', 'review_scores_rating',
#        'review_scores_accuracy', 'review_scores_cleanliness',
#        'review_scores_checkin', 'review_scores_communication',
#        'review_scores_location', 'review_scores_value', 'requires_license',
#        'instant_bookable', 'is_business_travel_ready',
#        'require_guest_profile_picture', 'require_guest_phone_verification',
#        'calculated_host_listings_count', 'reviews_per_month',
#        'host_emailverified', 'host_phoneverified', 'host_hasjumio',
#        'host_reviewverified', 'host_selfieverified', 'Air conditioning',
#        'Family/kid friendly', 'Host greets you', 'Laptop friendly workspace',
#        'Paid parking off premises', 'Patio or balcony',
#        'Luggage dropoff allowed', 'Long term stays allowed', 'Smoking allowed',
#        'Step-free access', 'Paid parking on premises'],
#       dtype='object')

# %%
dfD[noStrCol].isnull().sum()
# Out:
# id                                  0
# host_id                             0
# host_is_superhost                   0
# host_total_listings_count           0
# host_has_profile_pic                0
# host_identity_verified              0
# latitude                            0
# longitude                           0
# is_location_exact                   0
# accommodates                        0
# bathrooms                           0
# bedrooms                            0
# beds                                0
# price                               0
# security_deposit                    0
# cleaning_fee                        0
# guests_included                     0
# extra_people                        0
# minimum_nights                      0
# maximum_nights                      0
# availability_365                    0
# number_of_reviews                   0
# review_scores_rating                0
# review_scores_accuracy              0
# review_scores_cleanliness           0
# review_scores_checkin               0
# review_scores_communication         0
# review_scores_location              0
# review_scores_value                 0
# requires_license                    0
# instant_bookable                    0
# is_business_travel_ready            0
# require_guest_profile_picture       0
# require_guest_phone_verification    0
# calculated_host_listings_count      0
# reviews_per_month                   0
# host_emailverified                  0
# host_phoneverified                  0
# host_hasjumio                       0
# host_reviewverified                 0
# host_selfieverified                 0
# Air conditioning                    0
# Family/kid friendly                 0
# Host greets you                     0
# Laptop friendly workspace           0
# Paid parking off premises           0
# Patio or balcony                    0
# Luggage dropoff allowed             0
# Long term stays allowed             0
# Smoking allowed                     0
# Step-free access                    0
# Paid parking on premises            0
# dtype: int64

# %%
dfD['number_of_reviews'].value_counts()
# Out:
# 1      3971
# 2      2900
# 3      2192
# 4      1729
# 5      1477
#        ...
# 339       1
# 434       1
# 402       1
# 370       1
# 511       1
# Name: number_of_reviews, Length: 426, dtype: int64

# %%
DropC = ['host_id', 'first_review']
dfD.drop(DropC, axis = 1, inplace = True)

# %%
DropR = dfD[(dfD['year'] == '2019')&(dfD['month'] == '12')].index
dfD.drop(DropR, axis = 0, inplace = True)

# %%
dfD.groupby(['year', 'month'])['price'].count()
# Out:
# year  month
# 2018  04       15391
# 2019  01       13821
#       04       13749
# Name: price, dtype: int64

# %%
dfD.shape
# Out:
# (42961, 69)

# %%
dfD.to_csv('/home/guillem/DadesAirBNB/cleandataset.csv')

# %%
dfD['id']
# Out:
# 35932     8127277
# 35933    10172298
# 35934    10735872
# 35935    19432305
# 35936    20956172
#            ...
# 17643    33552923
# 17687    33586818
# 17688    33587186
# 17715    33611409
# 17733    33622725
# Name: id, Length: 42961, dtype: int64
